# %% [markdown]
# ## Unsupervised Learning Group Activity - Week 9
#
# ###### Images will only load if you are connected to the internet.
#
#
# A cool application of unsupervised learning that is highly relevant at RV is to analyze a corpus of text to identify clusters or topics present in the corpus.
#
# RV produces ~130k pieces of content a year (as of 2022), and spends approx. \\$70MM on content production, and our content heavy businesses generate on the order of \\$1BB in revenue.
#
# For those reasons - it seems like a good idea to be able to analyze and categorize our content to form groups - to then join to performance data/seo data to understand what works well, what works poorly, which types of content should we invest in more etc. This is something we have done in the past with manual editor tags or site folders, but that can often be inconsistent and subject to human error that makes proper analysis and grouping basically impossible - especially on larger sites or when taking an RV portfolio viewpoint.
#
# We actually have a product at Red Ventures that serves this use case called the Content Platform - this tool powers a variety of capabilities around content analysis, website personalizatoin and contextual ad targeting. You can read more about that technology here - it was unsupervised learning to "discover" the global RV tag taxonomy from data, and then a supervised learning task to classify new articles - https://redventures.atlassian.net/wiki/spaces/CP/pages/19585532184/Global+Tagging+Model
#
#
# In this activity we will take a sample of ~10k articles from the M&C vertical, turn the unstructured text into numeric data to feed to a model, and apply an unsupervised technique called "topic modelling" to the dataset.
# Topic modelling is very similar to clustering - one of the most common and powerful tools for topic modelling is called "Latent Dirichlet Allocation" (LDA) - https://www.jmlr.org/papers/volume3/blei03a/blei03a.pdf
#
# <img src="https://www.researchgate.net/profile/Amir-Karami/publication/325976766/figure/fig1/AS:641555870253057@1529970247271/Intuition-Behind-LDA-2.png">

# %% [markdown]
# ### LDA Intuition
#
# At a high level the LDA model attempts to model two probability distributions given data that is "words present in documents".
#
# 1. The probability of a topic over words - $p(word|topic)$ - Each "Topic" is a probability distribution over the words in that topic - for example a topic about sports might have high likelihood words such as "basketball, referree, football".
#
# 2. The probability of a document over topics $p(topics|document)$ - Each document can be represented as a probability distribution over "topics" by using the words in the document and the distribution above - for example an article about Davidson beating Duke at basketball might have high likelihood over topics for sports and college.
#
#
# The approach above makes this model very cool and flexible - providing "soft"/probabalistic membership of documents into many topics - and the choice of the Dirichlet distribution helps to make topics distinct from one another.
# Additionally while it is "famous" for working on text - LDA is just an unsupervised learning algorithm that can be used for several downstream algorithms similar to most clustering or matrix factorization algorithms.
# If you really want to go deep on the math we've linked the original paper by David Blei and team above.
#
# <img src = "https://www.researchgate.net/publication/346801402/figure/fig1/AS:986776055345152@1612277153515/LDA-underlying-intuition-Generation-of-documents-through-topics-following-the-Dirichlet.png">

# %% [markdown]
# ### Load dependencies and helper functions

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import math


def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(math.ceil(len(model.components_)/5), 5, figsize=(20, 6*math.ceil(len(model.components_)/5)), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()
    

def get_topic_names(model, feature_names, n_top_words):
    topic_names = []
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        top_features = [str(topic_idx+1)]+top_features
        topic_names.append("_".join(top_features))
        
        
    return topic_names

# %% [markdown]
# ### We created a clean data set of articles, titles and most recent publish dates for this exercise - you can find the dataset here -

# %%
data = pd.read_csv("./data/wp_posts_cleaned.csv")

# %%
data.head()
# Out:
#                                                title  \
# 0  9 eventos de Halloween que no te puedes perder...
# 1  8 terrazas únicas donde puedes tomarte un buen...
# 2    Todo lo que puedes hacer en Caguas con solo $30
# 3  Jazz, laberintos embrujados y otras 8 activida...
# 4  3 restaurantes que dan cátedra de recuperación...
#
#                                              content  \
# 0  Por si andas buscando a qué fiesta llegar ante...
# 1  En Puerto Rico no faltan los coffee shops. Ya ...
# 2  En el amplio valle de Caguas puedes toparte co...
# 3  Llegó el mes de las brujas y con él, todas las...
# 4  A la hora de ser solidarios en la recuperación...
#
#                                                 link                 date  \
# 0  https://www.plateapr.com/eventos-de-halloween-...  2022-10-14T07:05:00
# 1  https://www.plateapr.com/terrazas-unicas-donde...  2022-10-13T13:18:57
# 2  https://www.plateapr.com/que-hacer-en-caguas-p...  2022-10-11T14:20:40
# 3  https://www.plateapr.com/que-hacer-este-fin-de...  2022-10-07T02:24:00
# 4  https://www.plateapr.com/restaurantes-recupera...  2022-10-05T17:27:05
#
#    author  type
# 0      13  post
# 1      13  post
# 2      13  post
# 3      13  post
# 4      34  post

# %%
data.shape
# Out:
# (184, 6)

# %%
texts = data.content

# %% [markdown]
# ### Vectorizing Text
#
# First, we're going to turn our original unstructured data (raw text) into a form usable by ML models.
#
# The technique we are going to use to turn our text data into a numeric matrix is called "bag of words" -
# - 1 document = 1 row
# - 1 word in our vocabulary = 1 column
# - each entry = count of occurences of that word (column) in that document (row)
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html#sklearn.feature_extraction.text.CountVectorizer

# %%
# Stop Words in spanish from: https://github.com/Alir3z4/stop-words/blob/master/spanish.txt

# %%
stop_words = []

with open("./data/stop_words.txt", "r") as file:
    stop_words = file.readlines()
stop_words = [s.strip().lower() for s in stop_words]
stop_words
# Out:
# ['a',
#  'actualmente',
#  'adelante',
#  'además',
#  'afirmó',
#  'agregó',
#  'ahora',
#  'ahí',
#  'al',
#  'algo',
#  'alguna',
#  'algunas',
#  'alguno',
#  'algunos',
#  'algún',
#  'alrededor',
#  'ambos',
#  'ampleamos',
#  'ante',
#  'anterior',
#  'antes',
#  'apenas',
#  'aproximadamente',
#  'aquel',
#  'aquellas',
#  'aquellos',
#  'aqui',
#  'aquí',
#  'arriba',
#  'aseguró',
#  'así',
#  'atras',
#  'aunque',
#  'ayer',
#  'añadió',
#  'aún',
#  'bajo',
#  'bastante',
#  'bien',
#  'buen',
#  'buena',
#  'buenas',
#  'bueno',
#  'buenos',
#  'cada',
#  'casi',
#  'cerca',
#  'cierta',
#  'ciertas',
#  'cierto',
#  'ciertos',
#  'cinco',
#  'comentó',
#  'como',
#  'con',
#  'conocer',
#  'conseguimos',
#  'conseguir',
#  'considera',
#  'consideró',
#  'consigo',
#  'consigue',
#  'consiguen',
#  'consigues',
#  'contra',
#  'cosas',
#  'creo',
#  'cual',
#  'cuales',
#  'cualquier',
#  'cuando',
#  'cuanto',
#  'cuatro',
#  'cuenta',
#  'cómo',
#  'da',
#  'dado',
#  'dan',
#  'dar',
#  'de',
#  'debe',
#  'deben',
#  'debido',
#  'decir',
#  'dejó',
#  'del',
#  'demás',
#  'dentro',
#  'desde',
#  'después',
#  'dice',
#  'dicen',
#  'dicho',
#  'dieron',
#  'diferente',
#  'diferentes',
#  'dijeron',
#  'dijo',
#  'dio',
#  'donde',
#  'dos',
#  'durante',
#  'e',
#  'ejemplo',
#  'el',
#  'ella',
#  'ellas',
#  'ello',
#  'ellos',
#  'embargo',
#  'empleais',
#  'emplean',
#  'emplear',
#  'empleas',
#  'empleo',
#  'en',
#  'encima',
#  'encuentra',
#  'entonces',
#  'entre',
#  'era',
#  'erais',
#  'eramos',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estais',
#  'estamos',
#  'estan',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'ex',
#  'existe',
#  'existen',
#  'explicó',
#  'expresó',
#  'fin',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'gran',
#  'grandes',
#  'gueno',
#  'ha',
#  'haber',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'hace',
#  'haceis',
#  'hacemos',
#  'hacen',
#  'hacer',
#  'hacerlo',
#  'haces',
#  'hacia',
#  'haciendo',
#  'hago',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hecho',
#  'hemos',
#  'hicieron',
#  'hizo',
#  'hoy',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'igual',
#  'incluso',
#  'indicó',
#  'informó',
#  'intenta',
#  'intentais',
#  'intentamos',
#  'intentan',
#  'intentar',
#  'intentas',
#  'intento',
#  'ir',
#  'junto',
#  'la',
#  'lado',
#  'largo',
#  'las',
#  'le',
#  'les',
#  'llegó',
#  'lleva',
#  'llevar',
#  'lo',
#  'los',
#  'luego',
#  'lugar',
#  'manera',
#  'manifestó',
#  'mayor',
#  'me',
#  'mediante',
#  'mejor',
#  'mencionó',
#  'menos',
#  'mi',
#  'mientras',
#  'mio',
#  'mis',
#  'misma',
#  'mismas',
#  'mismo',
#  'mismos',
#  'modo',
#  'momento',
#  'mucha',
#  'muchas',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'nadie',
#  'ni',
#  'ninguna',
#  'ningunas',
#  'ninguno',
#  'ningunos',
#  'ningún',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'nueva',
#  'nuevas',
#  'nuevo',
#  'nuevos',
#  'nunca',
#  'o',
#  'ocho',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'parece',
#  'parte',
#  'partir',
#  'pasada',
#  'pasado',
#  'pero',
#  'pesar',
#  'poca',
#  'pocas',
#  'poco',
#  'pocos',
#  'podeis',
#  'podemos',
#  'poder',
#  'podria',
#  'podriais',
#  'podriamos',
#  'podrian',
#  'podrias',
#  'podrá',
#  'podrán',
#  'podría',
#  'podrían',
#  'poner',
#  'por',
#  'por qué',
#  'porque',
#  'posible',
#  'primer',
#  'primera',
#  'primero',
#  'primeros',
#  'principalmente',
#  'propia',
#  'propias',
#  'propio',
#  'propios',
#  'próximo',
#  'próximos',
#  'pudo',
#  'pueda',
#  'puede',
#  'pueden',
#  'puedo',
#  'pues',
#  'que',
#  'quedó',
#  'queremos',
#  'quien',
#  'quienes',
#  'quiere',
#  'quién',
#  'qué',
#  'realizado',
#  'realizar',
#  'realizó',
#  'respecto',
#  'sabe',
#  'sabeis',
#  'sabemos',
#  'saben',
#  'saber',
#  'sabes',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'segunda',
#  'segundo',
#  'según',
#  'seis',
#  'ser',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'señaló',
#  'si',
#  'sido',
#  'siempre',
#  'siendo',
#  'siete',
#  'sigue',
#  'siguiente',
#  'sin',
#  'sino',
#  'sobre',
#  'sois',
#  'sola',
#  'solamente',
#  'solas',
#  'solo',
#  'solos',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'sólo',
#  'tal',
#  'también',
#  'tampoco',
#  'tan',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'teneis',
#  'tenemos',
#  'tener',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'tercera',
#  'ti',
#  'tiempo',
#  'tiene',
#  'tienen',
#  'tienes',
#  'toda',
#  'todas',
#  'todavía',
#  'todo',
#  'todos',
#  'total',
#  'trabaja',
#  'trabajais',
#  'trabajamos',
#  'trabajan',
#  'trabajar',
#  'trabajas',
#  'trabajo',
#  'tras',
#  'trata',
#  'través',
#  'tres',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'ultimo',
#  'un',
#  'una',
#  'unas',
#  'uno',
#  'unos',
#  'usa',
#  'usais',
#  'usamos',
#  'usan',
#  'usar',
#  'usas',
#  'uso',
#  'usted',
#  'va',
#  'vais',
#  'valor',
#  'vamos',
#  'van',
#  'varias',
#  'varios',
#  'vaya',
#  'veces',
#  'ver',
#  'verdad',
#  'verdadera',
#  'verdadero',
#  'vez',
#  'vosotras',
#  'vosotros',
#  'voy',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos',
#  'ésta',
#  'éstas',
#  'éste',
#  'éstos',
#  'última',
#  'últimas',
#  'último',
#  'últimos',
#  'a',
#  'actualmente',
#  'adelante',
#  'además',
#  'afirmó',
#  'agregó',
#  'ahora',
#  'ahí',
#  'al',
#  'algo',
#  'alguna',
#  'algunas',
#  'alguno',
#  'algunos',
#  'algún',
#  'alrededor',
#  'ambos',
#  'ampleamos',
#  'ante',
#  'anterior',
#  'antes',
#  'apenas',
#  'aproximadamente',
#  'aquel',
#  'aquellas',
#  'aquellos',
#  'aqui',
#  'aquí',
#  'arriba',
#  'aseguró',
#  'así',
#  'atras',
#  'aunque',
#  'ayer',
#  'añadió',
#  'aún',
#  'bajo',
#  'bastante',
#  'bien',
#  'buen',
#  'buena',
#  'buenas',
#  'bueno',
#  'buenos',
#  'cada',
#  'casi',
#  'cerca',
#  'cierta',
#  'ciertas',
#  'cierto',
#  'ciertos',
#  'cinco',
#  'comentó',
#  'como',
#  'con',
#  'conocer',
#  'conseguimos',
#  'conseguir',
#  'considera',
#  'consideró',
#  'consigo',
#  'consigue',
#  'consiguen',
#  'consigues',
#  'contra',
#  'cosas',
#  'creo',
#  'cual',
#  'cuales',
#  'cualquier',
#  'cuando',
#  'cuanto',
#  'cuatro',
#  'cuenta',
#  'cómo',
#  'da',
#  'dado',
#  'dan',
#  'dar',
#  'de',
#  'debe',
#  'deben',
#  'debido',
#  'decir',
#  'dejó',
#  'del',
#  'demás',
#  'dentro',
#  'desde',
#  'después',
#  'dice',
#  'dicen',
#  'dicho',
#  'dieron',
#  'diferente',
#  'diferentes',
#  'dijeron',
#  'dijo',
#  'dio',
#  'donde',
#  'dos',
#  'durante',
#  'e',
#  'ejemplo',
#  'el',
#  'ella',
#  'ellas',
#  'ello',
#  'ellos',
#  'embargo',
#  'empleais',
#  'emplean',
#  'emplear',
#  'empleas',
#  'empleo',
#  'en',
#  'encima',
#  'encuentra',
#  'entonces',
#  'entre',
#  'era',
#  'erais',
#  'eramos',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estais',
#  'estamos',
#  'estan',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'ex',
#  'existe',
#  'existen',
#  'explicó',
#  'expresó',
#  'fin',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'gran',
#  'grandes',
#  'gueno',
#  'ha',
#  'haber',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'hace',
#  'haceis',
#  'hacemos',
#  'hacen',
#  'hacer',
#  'hacerlo',
#  'haces',
#  'hacia',
#  'haciendo',
#  'hago',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hecho',
#  'hemos',
#  'hicieron',
#  'hizo',
#  'hoy',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'igual',
#  'incluso',
#  'indicó',
#  'informó',
#  'intenta',
#  'intentais',
#  'intentamos',
#  'intentan',
#  'intentar',
#  'intentas',
#  'intento',
#  'ir',
#  'junto',
#  'la',
#  'lado',
#  'largo',
#  'las',
#  'le',
#  'les',
#  'llegó',
#  'lleva',
#  'llevar',
#  'lo',
#  'los',
#  'luego',
#  'lugar',
#  'manera',
#  'manifestó',
#  'mayor',
#  'me',
#  'mediante',
#  'mejor',
#  'mencionó',
#  'menos',
#  'mi',
#  'mientras',
#  'mio',
#  'mis',
#  'misma',
#  'mismas',
#  'mismo',
#  'mismos',
#  'modo',
#  'momento',
#  'mucha',
#  'muchas',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'nadie',
#  'ni',
#  'ninguna',
#  'ningunas',
#  'ninguno',
#  'ningunos',
#  'ningún',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'nueva',
#  'nuevas',
#  'nuevo',
#  'nuevos',
#  'nunca',
#  'o',
#  'ocho',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'parece',
#  'parte',
#  'partir',
#  'pasada',
#  'pasado',
#  'pero',
#  'pesar',
#  'poca',
#  'pocas',
#  'poco',
#  'pocos',
#  'podeis',
#  'podemos',
#  'poder',
#  'podria',
#  'podriais',
#  'podriamos',
#  'podrian',
#  'podrias',
#  'podrá',
#  'podrán',
#  'podría',
#  'podrían',
#  'poner',
#  'por',
#  'por qué',
#  'porque',
#  'posible',
#  'primer',
#  ...]

# %%
#define our vectorizer class
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=10000, stop_words=stop_words, ngram_range=(1, 2))

# %%
#fit the vectorizer to our text data and apply the transformation
tf = tf_vectorizer.fit_transform(texts)
# Out:
# /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages/sklearn/feature_extraction/text.py:404: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['puerto', 'rico'] not in stop_words.
#   warnings.warn(

# %%
# Each document is now a 1x10000 matrix as described above, and we have 10000 documents
print("Shape =",tf.shape)
tf[0]
# Out:
# Shape = (184, 10000)
# <1x10000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 353 stored elements in Compressed Sparse Row format>

# %%
tf_vectorizer.vocabulary_
# Out:
# {'andas': 1239,
#  'buscando': 2118,
#  'fiesta': 4720,
#  'llegar': 5608,
#  'acabe': 851,
#  'semana': 8466,
#  'brujas': 2055,
#  'lista': 5581,
#  'decidir': 3749,
#  'favorita': 4696,
#  'parques': 6439,
#  'eventos': 4575,
#  'pet': 6613,
#  'friendly': 4822,
#  'excusa': 4593,
#  'dejar': 3794,
#  'pasar': 6453,
#  'celebración': 2620,
#  'año': 1600,
#  'dejamos': 3789,
#  'nueve': 6180,
#  'debes': 3737,
#  'perder': 6534,
#  'resto': 7945,
#  'mes': 5919,
#  'house': 5162,
#  'phobia': 6620,
#  '2022': 489,
#  'puerto': 7368,
#  'rico': 7970,
#  'san': 8342,
#  'juan': 5367,
#  'dónde': 4273,
#  'mall': 5746,
#  'cuándo': 3643,
#  'viernes': 9634,
#  'lunes': 5710,
#  '31': 582,
#  'octubre': 6207,
#  'detalles': 3934,
#  'regresa': 7689,
#  'antiguo': 1266,
#  'local': 5643,
#  'piso': 6696,
#  'the': 9014,
#  '60': 695,
#  'mil': 5942,
#  'pies': 6655,
#  'cuadrados': 3533,
#  'puro': 7407,
#  'terror': 8995,
#  'adrenalina': 952,
#  'múltiples': 6076,
#  'atracciones': 1472,
#  'dj': 4178,
#  'vivo': 9803,
#  'personajes': 6578,
#  'tenebrosos': 8971,
#  'tomarse': 9116,
#  'fotos': 4790,
#  'boletos': 1935,
#  '24': 507,
#  '50': 662,
#  'ivu': 5322,
#  'taquillas': 8923,
#  'soul': 8681,
#  'screams': 8406,
#  'haunted': 5037,
#  'jardín': 5342,
#  'botánico': 1987,
#  'cultural': 3613,
#  'william': 9877,
#  'miranda': 5963,
#  'marín': 5838,
#  'caguas': 2213,
#  'jueves': 5405,
#  '13': 369,
#  'domingo': 4183,
#  'noviembre': 6177,
#  'casa': 2518,
#  'embrujada': 4351,
#  'undécima': 9381,
#  'temporada': 8963,
#  'park': 6420,
#  'caribe': 2424,
#  'witches': 9889,
#  'ritual': 8059,
#  'deadly': 3727,
#  'único': 9991,
#  'abduction': 820,
#  'isla': 5300,
#  'boleto': 1933,
#  'regular': 7697,
#  'comienza': 3081,
#  '26': 527,
#  '00': 0,
#  'ticketera': 9034,
#  'com': 2988,
#  'nights': 6145,
#  'añasco': 1594,
#  'don': 4218,
#  '12': 335,
#  'estaciones': 4540,
#  'susto': 8819,
#  'laberinto': 5487,
#  'entrar': 4423,
#  'salir': 8304,
#  'menores': 5890,
#  'años': 1603,
#  'acompañados': 890,
#  'adulto': 959,
#  'comienzan': 3087,
#  '23': 504,
#  '90': 783,
#  'panic': 6390,
#  'road': 8071,
#  'anfiteatro': 1245,
#  'tito': 9088,
#  'puente': 7359,
#  'llega': 5603,
#  'safe': 8279,
#  'sobrevivir': 8638,
#  'zonas': 9943,
#  'apocalípticas': 1301,
#  'encontrarás': 4388,
#  'zombies': 9935,
#  'criaturas': 3485,
#  'áreas': 9968,
#  'final': 4728,
#  'música': 6077,
#  'barra': 1687,
#  'grande': 4935,
#  'food': 4774,
#  'trucks': 9287,
#  'oportunidad': 6287,
#  'prisioneras': 7163,
#  'recorrido': 7626,
#  '20': 469,
#  'pr': 7026,
#  'niños': 6151,
#  'doggie': 4182,
#  'mansion': 5761,
#  'guaynabo': 4970,
#  'centro': 2648,
#  '14': 376,
#  'atrevidos': 1492,
#  'scarecrow': 8403,
#  'maze': 5853,
#  'familia': 4649,
#  'spooky': 8694,
#  'rooms': 8152,
#  'sorpresas': 8675,
#  'trick': 9268,
#  'or': 6293,
#  'treat': 9249,
#  'enjoy': 4399,
#  'full': 4851,
#  'moon': 6014,
#  'comercial': 3037,
#  'plaza': 6899,
#  'américas': 1231,
#  'tienda': 9037,
#  'galería': 4871,
#  'dark': 3686,
#  'fajardo': 4641,
#  '28': 533,
#  'experiencia': 4597,
#  'creativa': 3461,
#  'puedes': 7325,
#  'taquilla': 8922,
#  'evento': 4573,
#  'arte': 1380,
#  'pizza': 6706,
#  'costo': 3412,
#  '35': 598,
#  'reserva': 7770,
#  'espacio': 4471,
#  'fok': 4770,
#  'brewing': 2022,
#  '16': 413,
#  'esperando': 4520,
#  'semanas': 8479,
#  'ofrecerán': 6244,
#  'distintas': 4155,
#  'actividades': 912,
#  'honor': 5114,
#  'pregunta': 7095,
#  'cerveza': 2692,
#  'bayamón': 1745,
#  'sábado': 8823,
#  '29': 536,
#  'casco': 2552,
#  'celebrará': 2628,
#  'menú': 5897,
#  'delicioso': 3823,
#  'preparado': 7113,
#  'bucanero': 2079,
#  'pit': 6702,
#  'apto': 1340,
#  'andas buscando': 1241,
#  'pet friendly': 6614,
#  'dejar pasar': 3796,
#  'debes perder': 3741,
#  'house phobia': 5165,
#  'phobia 2022': 6621,
#  '2022 puerto': 491,
#  'puerto rico': 7370,
#  'rico san': 8013,
#  'san juan': 8350,
#  'juan dónde': 5384,
#  'mall san': 5747,
#  'juan san': 5394,
#  'juan cuándo': 5382,
#  'cuándo viernes': 3648,
#  'viernes lunes': 9653,
#  'lunes 31': 5711,
#  '31 octubre': 583,
#  'octubre 2022': 6208,
#  '2022 detalles': 490,
#  'detalles regresa': 3938,
#  'regresa house': 7690,
#  'phobia año': 6622,
#  'año antiguo': 1601,
#  'antiguo local': 1269,
#  'piso the': 6697,
#  'the mall': 9018,
#  '60 mil': 696,
#  'pies cuadrados': 6657,
#  'cuadrados puro': 3534,
#  'puro terror': 7408,
#  'terror adrenalina': 8996,
#  'adrenalina múltiples': 954,
#  'atracciones dj': 1474,
#  'vivo personajes': 9812,
#  'personajes tenebrosos': 6579,
#  'tenebrosos tomarse': 8972,
#  'tomarse fotos': 9117,
#  'boletos 24': 1936,
#  '24 50': 508,
#  '50 ivu': 664,
#  'ivu taquillas': 5323,
#  'soul screams': 8682,
#  'screams haunted': 8407,
#  'haunted house': 5038,
#  'jardín botánico': 5344,
#  'botánico cultural': 1989,
#  'cultural william': 3616,
#  'william miranda': 9878,
#  'miranda marín': 5964,
#  'caguas cuándo': 2217,
#  'cuándo jueves': 3646,
#  'jueves 13': 5411,
#  '13 domingo': 370,
#  'domingo noviembre': 4201,
#  'noviembre 2022': 6178,
#  'detalles casa': 3936,
#  'casa embrujada': 2529,
#  'regresa undécima': 7691,
#  'undécima temporada': 9382,
#  'temporada terror': 8964,
#  'terror screams': 8999,
#  'screams park': 8408,
#  'rico caribe': 7981,
#  'caribe atracciones': 2425,
#  'atracciones terror': 1476,
#  'terror the': 9000,
#  'the witches': 9025,
#  'witches ritual': 9890,
#  'ritual deadly': 8060,
#  'deadly mutants': 3728,
#  'único abduction': 9992,
#  'abduction house': 821,
#  'house isla': 5163,
#  'boleto regular': 1934,
#  'regular comienza': 7698,
#  'comienza 26': 3082,
#  '26 00': 528,
#  '00 ivu': 8,
#  'taquillas ticketera': 8925,
#  'ticketera com': 9035,
#  'añasco dónde': 1597,
#  'dónde don': 4276,
#  'añasco cuándo': 1596,
#  'detalles 12': 3935,
#  '12 estaciones': 344,
#  'susto casa': 8820,
#  'embrujada laberinto': 4352,
#  'laberinto terror': 5488,
#  'terror entrar': 8998,
#  'salir menores': 8308,
#  'menores 12': 5891,
#  '12 años': 342,
#  'años acompañados': 1604,
#  'acompañados adulto': 891,
#  'adulto boletos': 960,
#  'boletos comienzan': 1937,
#  'comienzan 23': 3089,
#  '23 90': 505,
#  '90 ivu': 784,
#  'panic road': 6391,
#  'road san': 8073,
#  'anfiteatro tito': 1246,
#  'tito puente': 9089,
#  'puente san': 7362,
#  'cuándo lunes': 3647,
#  'detalles llega': 3937,
#  'safe heaven': 8280,
#  'sobrevivir panic': 8639,
#  'road zonas': 8076,
#  'zonas apocalípticas': 9944,
#  'apocalípticas encontrarás': 1302,
#  'zombies gangas': 9936,
#  'criaturas extrañas': 3486,
#  'áreas exterminación': 9969,
#  'música vivo': 6078,
#  'vivo barra': 9804,
#  'barra grande': 1688,
#  'food trucks': 4777,
#  'trucks oportunidad': 9288,
#  'criaturas prisioneras': 3487,
#  'prisioneras boletos': 7164,
#  'boletos recorrido': 1938,
#  'recorrido comienzan': 7628,
#  'comienzan 20': 3088,
#  '20 00': 470,
#  'dónde centro': 4274,
#  'cuándo 14': 3644,
#  '14 31': 377,
#  'terror atracciones': 8997,
#  'atracciones atrevidos': 1473,
#  'atrevidos scarecrow': 1493,
#  'scarecrow maze': 8404,
#  'maze familia': 5854,
#  'familia spooky': 4653,
#  'spooky rooms': 8695,
#  'rooms sorpresas': 8153,
#  'sorpresas trick': 8676,
#  'trick or': 9269,
#  'or treat': 6295,
#  'full moon': 4852,
#  'moon mansion': 6015,
#  'centro comercial': 2652,
#  'comercial plaza': 3038,
#  'plaza américas': 6902,
#  'américas antiguo': 1232,
#  'tienda galería': 9039,
#  'años puedes': 1608,
#  'caguas dónde': 2218,
#  'fok brewing': 4771,
#  'brewing caguas': 2023,
#  'cuándo domingo': 3645,
#  '16 octubre': 416,
#  'delicioso preparado': 3824,
#  'faltan': 4644,
#  'coffee': 2932,
#  'shops': 8549,
#  'comenzar': 3020,
#  'mañana': 5856,
#  'buscar': 2122,
#  'taza': 8943,
#  'tarde': 8926,
#  'opciones': 6274,
#  'sobran': 8632,
#  'disfrutes': 4143,
#  'tacita': 8876,
#  'gusto': 4984,
#  'terrazas': 8986,
#  'únicas': 9988,
#  'acogedoras': 883,
#  'disfrutar': 4090,
#  'café': 2172,
#  'hacienda': 5007,
#  'pedro': 6512,
#  'santurce': 8382,
#  'breakfast': 2009,
#  'avenida': 1540,
#  'josé': 5361,
#  'diego': 3961,
#  '00923': 175,
#  'brunch': 2057,
#  'spots': 8716,
#  'concurridos': 3184,
#  'ofrece': 6225,
#  'producto': 7208,
#  'artesanal': 1401,
#  'cuya': 3635,
#  'confección': 3215,
#  'data': 3710,
#  'fines': 4744,
#  'siglo': 8572,
#  'xix': 9902,
#  'cultiva': 3591,
#  'recoge': 7557,
#  'mano': 5759,
#  'elabora': 4327,
#  'cuidado': 3577,
#  'amor': 1217,
#  'comienzos': 3091,
#  'historia': 5092,
#  'allí': 1107,
#  'terraza': 8982,
#  'corazón': 3351,
#  'platea': 6757,
#  'tip': 9058,
#  'bolsas': 1940,
#  'date': 3711,
#  'vuelta': 9827,
#  'angie': 1248,
#  'filtrado': 4727,
#  '68': 716,
#  'francisco': 4796,
#  '00901': 137,
#  'aire': 1064,
#  'libre': 5538,
#  'viejo': 9620,
#  'gusta': 4979,
#  'comida': 3045,
#  'acompañar': 894,
#  'bebidas': 1780,
#  'refrescantes': 7663,
#  'ginger': 4908,
#  'iced': 5181,
#  'tea': 8950,
#  'aliviar': 1099,
#  'calor': 2301,
#  'acompaña': 887,
#  'galletas': 4872,
#  'veganas': 9519,
#  'pica': 6626,
#  'hambre': 5021,
#  'ordena': 6298,
#  'ensalada': 4402,
#  'granos': 4940,
#  'hidden': 5075,
#  'gem': 4893,
#  'comparte': 3100,
#  'boca': 1910,
#  'laboratorio': 5489,
#  'fotografía': 4789,
#  'opera': 6283,
#  'casita': 2560,
#  'miramar': 5959,
#  'lunch': 5701,
#  'dinner': 3985,
#  '605': 698,
#  'av': 1513,
#  '00907': 146,
#  'barras': 1693,
#  'criolla': 3488,
#  'fusión': 4859,
#  'nightlife': 6141,
#  'restaurantes': 7890,
#  'rooftop': 8143,
#  'auténtica': 1507,
#  'puertorriqueña': 7371,
#  'ambiente': 1184,
#  'elegante': 4338,
#  'cómodo': 3671,
#  'sirven': 8602,
#  'cócteles': 3664,
#  'tropicales': 9279,
#  'quieres': 7476,
#  'tomarte': 9118,
#  'conocida': 3233,
#  'cuarto': 3544,
#  'almuerzo': 1116,
#  'paso': 6474,
#  'cafecito': 2164,
#  'frente': 4808,
#  'restaurante': 7856,
#  'arquitectura': 1366,
#  'neo': 6132,
#  'capilla': 2392,
#  'señora': 8541,
#  'diseñada': 4046,
#  'arquitecto': 1365,
#  '1908': 453,
#  'cé': 3656,
#  '1765': 431,
#  'calle': 2250,
#  'loíza': 5680,
#  '00911': 159,
#  'familiar': 4654,
#  'parking': 6425,
#  'tipo': 9080,
#  'gustos': 4986,
#  'claro': 2829,
#  'spot': 8700,
#  'faltar': 4645,
#  'pequeño': 6531,
#  'sirve': 8600,
#  'postres': 7008,
#  'locales': 5647,
#  'disfruta': 4060,
#  'pie': 6644,
#  'cake': 2226,
#  'tomas': 9122,
#  'visitar': 9717,
#  'pásate': 7418,
#  'súper': 8865,
#  'mona': 5995,
#  'ropa': 8156,
#  'artículos': 1418,
#  'queda': 7434,
#  'pasos': 6476,
#  'shop': 8546,
#  'cafe': 2161,
#  'sombras': 8661,
#  'sur': 8801,
#  'favoritos': 4700,
#  'ubicado': 9352,
#  'montañas': 6003,
#  'yauco': 9908,
#  'toques': 9140,
#  'chocolate': 2772,
#  'caramelo': 2417,
#  'especias': 4510,
#  'cómoda': 3670,
#  'ofrecen': 6237,
#  'sandwiches': 8362,
#  'dulces': 4251,
#  'contar': 3279,
#  'curiosidad': 3627,
#  'ataque': 1453,
#  'patio': 6492,
#  'níspero': 6182,
#  'hotel': 5150,
#  'convento': 3307,
#  '100': 234,
#  'cristo': 3509,
#  'disfrutas': 4134,
#  'desayuno': 3862,
#  'tapas': 8907,
#  'recorrer': 7622,
#  'abiertas': 826,
#  'ensaladas': 4403,
#  'deliciosas': 3822,
#  'ideal': 5186,
#  'relax': 7716,
#  'compañía': 3122,
#  'sube': 8743,
#  'sebastián': 8414,
#  'respirar': 7836,
#  'salado': 8289,
#  'mar': 5777,
#  'comunión': 3162,
#  '1616': 418,
#  '25': 514,
#  '2017': 484,
#  'creativo': 3467,
#  'variedad': 9462,
#  'teses': 9001,
#  'jugos': 5425,
#  'naturales': 6098,
#  'sándwiches': 8861,
#  'hermosa': 5060,
#  'pasarla': 6459,
#  'salón': 8337,
#  'reuniones': 7955,
#  'corillo': 3366,
#  'jangueo': 5333,
#  'selfies': 8462,
#  'justo': 5443,
#  'red': 7647,
#  'pizzería': 6717,
#  'clásico': 2862,
#  'variado': 9456,
#  'muñoz': 6061,
#  '181': 439,
#  'lorenzo': 5673,
#  '00754': 122,
#  'ocasiones': 6195,
#  'tour': 9165,
#  'histórico': 5104,
#  'facilidades': 4638,
#  'público': 7430,
#  'conozca': 3245,
#  'raíces': 7524,
#  'procesos': 7196,
#  'vete': 9585,
#  'servido': 8528,
#  'linda': 5576,
#  'campo': 2356,
#  'espera': 4517,
#  'servirte': 8532,
#  'mereces': 5916,
#  'restaurant': 7847,
#  'pide': 6643,
#  'aprovecha': 1326,
#  'visita': 9690,
#  'almorzar': 1114,
#  'cenar': 2639,
#  'wanda': 9850,
#  'carrasquillo': 2497,
#  'diaz': 3957,
#  'hora': 5117,
#  'lugares': 5687,
#  'compartimos': 3106,
#  'lovers': 5678,
#  'espacios': 4488,
#  'disponibles': 4149,
#  'experiencias': 4605,
#  'placenteras': 6729,
#  'compartir': 3117,
#  'coffee shops': 2941,
#  'disfrutar café': 4101,
#  'café hacienda': 2191,
#  'hacienda san': 5010,
#  'san pedro': 8355,
#  'avenida josé': 1545,
#  'josé diego': 5362,
#  'diego san': 3962,
#  'brunch coffee': 2063,
#  'artesanal cuya': 1402,
#  'siglo xix': 8576,
#  'corazón santurce': 3358,
#  'platea tip': 6761,
#  'bolsas café': 1941,
#  'café date': 2186,
#  'date vuelta': 3717,
#  '68 san': 717,
#  'san francisco': 8345,
#  'francisco san': 4797,
#  'juan 00901': 5368,
#  '00901 aire': 138,
#  'aire libre': 1067,
#  'libre coffee': 5548,
#  'shops pet': 8556,
#  'viejo san': 9622,
#  'rico terraza': 8016,
#  'menú comida': 5902,
#  'bebidas refrescantes': 1783,
#  'aliviar calor': 1100,
#  'hidden gem': 5076,
#  'casita miramar': 2561,
#  'miramar lunch': 5961,
#  'lunch dinner': 5708,
#  'dinner 605': 4013,
#  '605 av': 699,
#  'av miramar': 1521,
#  'miramar san': 5962,
#  'juan 00907': 5369,
#  '00907 reserva': 156,
#  'reserva barras': 7774,
#  'barras comida': 1700,
#  'comida criolla': 3055,
#  'criolla comida': 3490,
#  'comida fusión': 3060,
#  'fusión hidden': 4862,
#  'gem nightlife': 4894,
#  'nightlife restaurantes': 6144,
#  'restaurantes rooftop': 7931,
#  'rooftop casita': 8146,
#  'comida auténtica': 3049,
#  'auténtica puertorriqueña': 1509,
#  'puedes disfrutar': 7334,
#  'disfrutar almuerzo': 4094,
#  'terraza puedes': 8984,
#  'café cé': 2185,
#  'cé 1765': 3657,
#  '1765 calle': 432,
#  'calle loíza': 2274,
#  'loíza san': 5681,
#  'juan 00911': 5371,
#  '00911 coffee': 161,
#  'shops familiar': 8552,
#  'familiar parking': 4668,
#  'parking restaurantes': 6430,
#  'queda pasos': 7437,
#  'coffee shop': 2940,
#  'brunch lunch': 2071,
#  'café historia': 2192,
#  'rico ubicado': 8017,
#  'ubicado viejo': 9370,
#  'hotel convento': 5154,
#  'convento 100': 3308,
#  '100 calle': 237,
#  'calle cristo': 2262,
#  'cristo san': 3510,
#  '00901 brunch': 141,
#  'shops comida': 8550,
#  'fusión familiar': 4861,
#  'familiar hidden': 4659,
#  'spot ofrece': 8705,
#  'desayuno brunch': 3864,
#  'tapas cócteles': 8909,
#  'puedes recorrer': 7353,
#  'café tarde': 2206,
#  'ideal pasar': 5189,
#  'pasar tarde': 6458,
#  'san sebastián': 8356,
#  'respirar aire': 7837,
#  'café comunión': 2182,
#  'comunión 1616': 3163,
#  '1616 pr': 419,
#  'pr 25': 7045,
#  '25 san': 518,
#  'jugos naturales': 5426,
#  'puedes pasarla': 7347,
#  'pasarla relax': 6461,
#  'ofrece menú': 6230,
#  'hacienda muñoz': 5009,
#  'muñoz pr': 6063,
#  'pr 181': 7042,
#  '181 san': 441,
#  'san lorenzo': 8352,
#  'lorenzo 00754': 5674,
#  'ocasiones café': 6196,
#  'tour histórico': 9167,
#  'ropa cómoda': 8157,
#  'aprovecha visita': 1329,
#  'almorzar cenar': 1115,
#  'isla compartimos': 5302,
#  'coffee lovers': 2938,
#  'amplio': 1224,
#  'valle': 9448,
#  'naturaleza': 6100,
#  'sal': 8283,
#  'usual': 9415,
#  'ruta': 8182,
#  'recorre': 7619,
#  'ciudad': 2817,
#  'día': 4259,
#  '30': 547,
#  'santiago': 8377,
#  'palmer': 6375,
#  'betances': 1843,
#  '00725': 93,
#  'best': 1820,
#  'completa': 3133,
#  'cultura': 3596,
#  'juegos': 5402,
#  'diversión': 4168,
#  'pública': 7423,
#  'alcaldía': 1079,
#  'recreo': 7635,
#  'combina': 2993,
#  'diseño': 4055,
#  'plazoleta': 6917,
#  'parque': 6433,
#  'invitamos': 5290,
#  'entera': 4408,
#  'agua': 1009,
#  'aviario': 1576,
#  'carrusel': 2514,
#  'plateatip': 6765,
#  'encuentras': 4392,
#  'kings': 5462,
#  'cream': 3444,
#  'heladería': 5048,
#  'icónica': 5182,
#  'vasito': 9501,
#  'pierdas': 6651,
#  'maíz': 5855,
#  'pa': 6338,
#  'enteres': 4409,
#  'budget': 2085,
#  'famosos': 4681,
#  'degustar': 3784,
#  'puertorriqueño': 7376,
#  'bizcochos': 1874,
#  'hechos': 5045,
#  'presupuesto': 7147,
#  'mallorca': 5748,
#  'recomendación': 7568,
#  'mallorcas': 5749,
#  'horarios': 5126,
#  'pm': 6925,
#  'lectura': 5518,
#  'estación': 4541,
#  'libros': 5562,
#  'libres': 5560,
#  'cercano': 2663,
#  'llévate': 5638,
#  'museo': 6044,
#  'luis': 5695,
#  'esquina': 4531,
#  'belvis': 1811,
#  'quédate': 7489,
#  'llégale': 5637,
#  'edificio': 4308,
#  'conocerás': 3231,
#  'municipio': 6040,
#  'piezas': 6661,
#  'llevará': 5628,
#  'martes': 5825,
#  'detente': 3943,
#  'rato': 7514,
#  'admirar': 946,
#  'estilo': 4553,
#  'arquitectónico': 1369,
#  'michael': 5936,
#  'conecta': 3200,
#  '156': 410,
#  '00726': 101,
#  'reconecta': 7609,
#  'cruzando': 3528,
#  'senderos': 8488,
#  'hermoso': 5068,
#  'conoce': 3223,
#  'viviente': 9797,
#  'flora': 4761,
#  'encontrar': 4384,
#  'elementos': 4341,
#  'entorno': 4413,
#  'incluyendo': 5222,
#  'ecología': 4282,
#  'turabo': 9304,
#  'zona': 9937,
#  'histórica': 5102,
#  'industria': 5228,
#  'azucarera': 1585,
#  'individual': 5226,
#  'arboleda': 1343,
#  'taína': 8946,
#  'africana': 974,
#  'miércoles': 5971,
#  '10': 219,
#  'sábados': 8844,
#  'domingos': 4202,
#  'pendiente': 6522,
#  'redes': 7649,
#  'sociales': 8642,
#  'talleres': 8892,
#  'educativos': 4316,
#  'predios': 7082,
#  'jardi': 5338,
#  'bota': 1977,
#  'nico': 6137,
#  '189': 450,
#  'km': 5469,
#  'brewery': 2018,
#  'truck': 9282,
#  'quizás': 7487,
#  'recomendaciones': 7562,
#  'darte': 3697,
#  'gustito': 4982,
#  'encanta': 4374,
#  'tratar': 9237,
#  'sabores': 8245,
#  'beer': 1790,
#  'exquisitos': 4622,
#  'platos': 6804,
#  'oferta': 6217,
#  'alitas': 1098,
#  'rica': 7965,
#  'hamburguesa': 5023,
#  'vegano': 9526,
#  'dejes': 3804,
#  'probar': 7184,
#  'vegana': 9517,
#  'prefieres': 7094,
#  'carne': 2441,
#  'recomendamos': 7600,
#  'burger': 2101,
#  'pasas': 6463,
#  'gurabo': 4978,
#  'río': 8197,
#  'cervecería': 2690,
#  'gratis': 4941,
#  'sobra': 8631,
#  'visites': 9742,
#  'siguientes': 8582,
#  'cercanos': 2664,
#  'rosada': 8164,
#  'carlos': 2438,
#  'manuel': 5772,
#  'tabaco': 8866,
#  'torres': 9154,
#  'pico': 6636,
#  'amarilla': 1176,
#  'concha': 3174,
#  'déjate': 4258,
#  'sorprender': 8673,
#  'limitado': 5571,
#  'móntate': 6075,
#  'carro': 2511,
#  'explorar': 4614,
#  'aseguramos': 1431,
#  'amarás': 1180,
#  'encantos': 4380,
#  'low': 5679,
#  'deseas': 3902,
#  'deleitar': 3810,
#  'paladar': 6366,
#  'descubrir': 3891,
#  'joyas': 5365,
#  'gastronómicas': 4889,
#  'comida ambiente': 3046,
#  'ambiente familiar': 1191,
#  'ruta recorre': 8189,
#  'ciudad criolla': 2821,
#  'lista actividades': 5582,
#  'centro ciudad': 2651,
#  'plaza santiago': 6914,
#  'santiago palmer': 8378,
#  'betances caguas': 1844,
#  'caguas 00725': 2214,
#  '00725 best': 95,
#  'best tarde': 1841,
#  'tarde completa': 8927,
#  'completa plaza': 3135,
#  'plaza aire': 6901,
#  'libre arte': 5539,
#  'arte cultura': 1386,
#  'cultura coffee': 3602,
#  'familiar juegos': 4662,
#  'juegos diversión': 5403,
#  'diversión parking': 4171,
#  'parking pet': 6428,
#  'friendly plaza': 4826,
#  'plaza pública': 6911,
#  'plaza recreo': 6912,
#  'plateatip plaza': 6788,
#  'kings cream': 5463,
#  'cream heladería': 3447,
#  'platea pa': 6758,
#  'pa enteres': 6339,
#  'breakfast brunch': 2013,
#  'calle betances': 2255,
#  'budget friendly': 2087,
#  'friendly caguas': 4823,
#  'pública plaza': 7426,
#  'café 100': 2173,
#  '100 puertorriqueño': 240,
#  'hechos casa': 5046,
#  'horarios lunes': 5130,
#  'lunes viernes': 5720,
#  'viernes 30': 9643,
#  '30 30': 550,
#  '30 pm': 554,
#  'pm sábado': 6933,
#  'sábado 00': 8824,
#  '00 30': 5,
#  'pm domingo': 6928,
#  'domingo 00': 4184,
#  'pm plateatip': 6931,
#  'plateatip gusta': 6776,
#  'museo arte': 6046,
#  'arte caguas': 1381,
#  'calle luis': 2275,
#  'cultura budget': 3599,
#  'museo historia': 6050,
#  'casa alcaldía': 2520,
#  'horarios martes': 5131,
#  'martes viernes': 5832,
#  'viernes 00': 9635,
#  '00 00': 1,
#  '00 pm': 11,
#  'conecta naturaleza': 3202,
#  'marín pr': 5839,
#  'pr 156': 7041,
#  '156 caguas': 411,
#  'caguas 00726': 2215,
#  '00726 caguas': 102,
#  'hermoso jardín': 5069,
#  'museo viviente': 6054,
#  'puedes encontrar': 7336,
#  'ecología valle': 4283,
#  'valle turabo': 9450,
#  'zona histórica': 9938,
#  'industria azucarera': 5229,
#  'horarios miércoles': 5132,
#  'miércoles viernes': 5979,
#  'viernes 10': 9637,
#  '10 00': 220,
#  'pm sábados': 6934,
#  'sábados domingos': 8858,
#  'domingos 10': 4205,
#  'plateatip pendiente': 6784,
#  'pendiente redes': 6523,
#  'redes sociales': 7650,
#  'talleres educativos': 8893,
#  'jardi bota': 5339,
#  'bota nico': 1978,
#  'nico caguas': 6138,
#  'brewing calle': 2024,
#  'calle 189': 2252,
#  '189 km': 451,
#  'km caguas': 5480,
#  '00725 aire': 94,
#  'libre brewery': 5543,
#  'brewery familiar': 2021,
#  'familiar food': 4656,
#  'food truck': 4776,
#  'truck música': 9284,
#  'vivo parking': 9811,
#  'darte gustito': 3703,
#  'spot combina': 8701,
#  'dejes probar': 3806,
#  'brewing cervecería': 2025,
#  'recomendamos visites': 7605,
#  'ciudad casa': 2820,
#  'casa rosada': 2543,
#  'tabaco herminio': 8867,
#  'deleitar paladar': 3811,
#  'descubrir joyas': 3893,
#  'lista restaurantes': 5585,
#  'restaurantes caguas': 7899,
#  'debes visitar': 3744,
#  ...}

# %%
#'tf_vectorizer.vocabulary_' this is our "vocabulary" that we inferred from the text 
#each word token we extracted and the count of that word token across the corpus
pd.DataFrame.from_dict(tf_vectorizer.vocabulary_,orient = "index").head(30)
# Out:
#                 0
# andas        1239
# buscando     2118
# fiesta       4720
# llegar       5608
# acabe         851
# semana       8466
# brujas       2055
# lista        5581
# decidir      3749
# favorita     4696
# parques      6439
# eventos      4575
# pet          6613
# friendly     4822
# excusa       4593
# dejar        3794
# pasar        6453
# celebración  2620
# año          1600
# dejamos      3789
# nueve        6180
# debes        3737
# perder       6534
# resto        7945
# mes          5919
# house        5162
# phobia       6620
# 2022          489
# puerto       7368
# rico         7970

# %% [markdown]
# ### Set up the LDA Model
#
# Similar to many clustering techniques, one of the main inputs to LDA is the number of topics - `n_components`.
#
# There are other related techniques that try to infer the number of topics from the data itself such as hierarchical LDA - but the "base" model requires that input.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.LatentDirichletAllocation.html

# %%
n_components = 40
n_top_words = 20

lda = LatentDirichletAllocation(
    n_components=n_components,
    max_iter=5,
    random_state=0,
    verbose = 2 # this could take a little bit, so we specify higher verbosity for some logs
)

# %% [markdown]
# ##### Fit our LDA model and store the topic distributions for each document in `clusters`

# %%
clusters = lda.fit_transform(tf)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# iteration: 1 of max_iter: 5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# iteration: 2 of max_iter: 5
# iteration: 3 of max_iter: 5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# iteration: 4 of max_iter: 5
# iteration: 5 of max_iter: 5
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s finished

# %% [markdown]
# ### Now, we can visualize our topics
#
# You can try playing around with different params and see what results you get.
#
# The main things to tune are:
# 1. The number of topics - `n_components`
# 2. The parameters of the CountVectorizer - which basically play with how many words you would extract from the text and some logic on top of that, and therefore how many/what type of columns you have in your vectorized matrix.

# %%
tf_feature_names = tf_vectorizer.get_feature_names_out()
plot_top_words(lda, tf_feature_names, n_top_words, "Topics in LDA model")

# %% [markdown]
# ### We can also visualize the topic distribution of a particular article - because of how the LDA model works
#
# The code below will take a random sample article and visualize the topic distribution of that text

# %%
#get topic "names" - by taking the 4 most likely word tokens in the topic
topic_names = get_topic_names(lda, feature_names=tf_feature_names, n_top_words=4)

# %%
sample_idx = np.random.choice(len(texts))
sample_idx
# Out:
# 90

# %%
print(texts[sample_idx])
# Out:
# Celebrar el amor es una ocasión de fiesta. Es el momento en que recordamos, vivimos y disfrutamos de ese ser especial en nuestra vida. Por eso, te dejamos los eventos más espectaculares en San Valentin, para que celebres a quienes amas como se debe: con estilo y romance. ¡Toma nota, que la lista viene intensa! Noche icónica en un cóctel bar 1 Antiguo 26 261 C. de Tetuán, San Juan, 00901 barras Nightlife Tapas Antiguo 26 Alta Coctelería El icónico cóctel bar de Viejo San Juan, Antiguo 26 se ha juntado con la Chef Pau para traerte una noche de San Valentín de comida asiática que enamorará tu paladar. El evento bajo el nombre de Asian Affair contará con cuatro cursos de una variedad de platos inspirados en la cocina asiática que te hará soñar con algún lugar distante junto a tu pareja. A las 6:30pm comienza el Cocktail Hour y a las 7:30pm la cena. Nota: Este evento está completamente vendido. Platea Tip: Acompaña tu comida con uno de los cocktails de la casa, Karrot. Ysi al terminar te quedas con ganas de algo dulce, date la vuelta por Anita Gelato en la calle Fortaleza. Fin de semana y varias opciones culinarias 2 Condado Vanderbilt 1055 Ashford Ave, San Juan, 00907 Condado Vanderbilt Hotel ¡Mil formas para enamorarte! Es lo que ofrecerá durante el fin de semana de los enamorados el Hotel Condado Vanderbilt. Preparando una galería gastronómica que se ajuste al deseo de cada paladar. Y es que sus cuatro restaurantes: 1919, Ola Ocean Front Bistro, Tacos & Tequila y STK SJ tendrán en la mesa distintas alternativas culinarias que recorren la cocina local e internacional para cumplir todos los gustos. El evento es de 6pm a 10pm, desde el viernes 11 al 14 de febrero. Reserva en tu opción predilecta a través de OpenTable. Platea Tip: Agrégale a tu fin de semana un tratamiento para parejas, Just you & Me, que también estará en oferta durante el fin de semana en The Spa Condado Vanderbilt. 3 Palacio Provincial 103 C. de San Francisco, San Juan, 00901 Boutique Hotels Hospedajes pet friendly Hotel Palacio Provincial Planifica tu cena de San Valentin en la terraza del Hotel Palacio Provincial con vista directa a la Bahía de San Juan. Bajo el diseño del Chef ejecutivo Victor Torres disfrutarás de una variedad de estaciones, cinco en total, en las que podrás degustar una gama de platos fríos y calientes con sabores de alta cocina. El recorrido finalizará con variados postres para endulzar el corazón. El evento es de 6:30pm a 10pm. Platea tip: Si quieres hacer de tu cena una estadía, visita su página web para que veas sus ofertas BOGO con hasta cincuenta por ciento de descuento. Celebración para todo tipo de amor 4 Rosa Elena Brunch Lunch 954 PR 25 Suite 101, San Juan, 00907 Reserva ahora Rosa & Elena Rosa y Elena invita a una cena de San Valentin dirigida a celebrar el amor como tu desees. En familia, pareja, amigos o hasta el crush. El restaurante que se destaca por su servicio familiar y ambiente acogedor abre las puertas al romance el 14 de febrero para que no te preocupes por nada que no sea disfrutar. El evento Tú y yo está diseñado para que cada pareja se sienta agasajada con la oferta que incluye dos aperitivos, un plato principal por persona y postre. El evento comienza a las 7:30 pm. Platea tip: Los espacios son limitados así que compra tu taquilla ya. 5 Condado Ocean Club 1045 Ashford Ave, San Juan 00907 Reserva ahora Aire libre Boutique Hotels Hospedajes Condado Ocean Club Con la idea de celebrar el amor en todas sus categorías Condado Ocean Club ha creado una serie de eventos que van desde gastronomía, estadías y hasta deporte. Amor a la gastronomía, será un evento que contará con opciones de brunch y cena en SOCIAL. Amor a la relajación total tendrá unas ofertas de estadía diseñadas para relajarse, disfrutar del hotel y elevar el romance, podrás elegir entre Eat, Pray, Loca y Better Together. Y para cerrar con los eventos de celebración el domingo se celebrará Amor por el deporte donde los fanáticos podrán disfrutar del Super Bow ...

# %%
pd.DataFrame(index= topic_names, data= clusters[sample_idx], columns = ["topic_probability"]).plot.bar(figsize = (15,10), rot=90)
plt.show()
