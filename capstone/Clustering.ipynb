# %%
from dotenv import dotenv_values
import requests
import openai
from tenacity import retry, wait_random_exponential, stop_after_attempt
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
config = dotenv_values(".env")
openai.api_key =  config['OPENAI_KEY']

# %%
# Reading the data
df = pd.read_csv("./data/wp_posts.csv")
df.head()
# Out:
#                                                title  \
# 0  9 eventos de Halloween que no te puedes perder...
# 1  8 terrazas únicas donde puedes tomarte un buen...
# 2    Todo lo que puedes hacer en Caguas con solo $30
# 3  Jazz, laberintos embrujados y otras 8 activida...
# 4  3 restaurantes que dan cátedra de recuperación...
#
#                                              content  \
# 0  Por si andas buscando a qué fiesta llegar ante...
# 1  En Puerto Rico no faltan los coffee shops. Ya ...
# 2  En el amplio valle de Caguas puedes toparte co...
# 3  Llegó el mes de las brujas y con él, todas las...
# 4  A la hora de ser solidarios en la recuperación...
#
#                                                 link                 date  \
# 0  https://www.plateapr.com/eventos-de-halloween-...  2022-10-14T07:05:00
# 1  https://www.plateapr.com/terrazas-unicas-donde...  2022-10-13T13:18:57
# 2  https://www.plateapr.com/que-hacer-en-caguas-p...  2022-10-11T14:20:40
# 3  https://www.plateapr.com/que-hacer-este-fin-de...  2022-10-07T02:24:00
# 4  https://www.plateapr.com/restaurantes-recupera...  2022-10-05T17:27:05
#
#    author  type
# 0      13  post
# 1      13  post
# 2      13  post
# 3      13  post
# 4      34  post

# %%
df.isnull().sum()
# Out:
# title      2
# content    1
# link       0
# date       0
# author     0
# type       0
# dtype: int64

# %%
len(df)
# Out:
# 187

# %%
df = df.dropna()

# %%
len(df)
# Out:
# 184

# %%
articles = [f for f in df.content.values]
titles = [t for t in df.title.values]

# %%
vectorizer = TfidfVectorizer(stop_words={'english'})
x_t_fid_vectorizer = vectorizer.fit_transform(articles)

# %%
def plot_kmeans_elbow_chart(X, max_ks=10):
    sum_of_squared_distances = []
    K = range(2,max_ks)
    for k in K:
        km = KMeans(n_clusters=k, max_iter=200, n_init=10)
        km = km.fit(X)
        sum_of_squared_distances.append(km.inertia_)
    plt.plot(K, sum_of_squared_distances, 'bx-')
    plt.xlabel('k')
    plt.ylabel('Sum_of_squared_distances')
    plt.title('Elbow Method For Optimal k')
    plt.show()
    
def k_means_cluster_analysis(k, X, titles):
    model = KMeans(n_clusters=k, init='k-means++', max_iter=200, n_init=10)
    model.fit(X)
    labels=model.labels_
    clustered=pd.DataFrame(list(zip(titles,labels)),columns=['title','cluster'])
    clustered = clustered.sort_values(by=['cluster']).reset_index(drop=True)
    print(f"\n\nClusters ---------------------------------------------------------------------------{k}")
    print(clustered['cluster'].value_counts())
    for cluster in range(true_k):
        temp = clustered[clustered['cluster']==cluster]
        print(f"\n\nCluster ---------------------------------------------------------------------------{cluster}")
        for title in temp['title'].values:
            print(title)

# %%
plot_kmeans_elbow_chart(x_t_fid_vectorizer, 10)

# %%
true_k = 4
k_means_cluster_analysis(true_k, x_t_fid_vectorizer, titles)
# Out:
# Clusters ---------------------------------------------------------------------------4
# 1    88
# 2    59
# 3    27
# 0    10
# Name: cluster, dtype: int64
#
#
# Cluster ---------------------------------------------------------------------------0
# Siete playas perfectas para escaparte y romper la rutina
# Siete restaurantes en Isabela para comer en tu próxima visita
# Ocho lugares para celebrar tu boda
# 17 paradas obligatorias para hacer en Rincón, Puerto Rico
# Bucket list: 14 cosas para hacer este verano en Puerto Rico
# Degustando Puerto Rico Restaurant Week (1-12 de junio de 2022)
# 9 actividades para hacer en Guánica, el pueblo del eterno verano
# Restaurantes de fine dining en Puerto Rico que debes probar
# 5 razones para visitar el Taste Food Fest en Plaza Las Américas
# 5 paradas que hacer en Isabela, Puerto Rico
#
#
# Cluster ---------------------------------------------------------------------------1
# Seis restaurantes en Rincón que tienes que probar
# Restaurantes para una experiencia farm-to-table
# Speakeasies que debes visitar en Puerto Rico
# Seis espacios de co-working para mantenerte conectado si se va la luz
# 6 restaurantes con vista a las montañas
# Cosas para hacer en 24 horas en el este
# Actividades para divertirse en familia en Puerto Rico
# Siete fincas locales que ofrecen servicio de delivery
# Ruta por Lares: Qué hacer y dónde comer
# Restaurantes para comer al aire libre
# 5 spots para comer nachos fuera de este mundo
# 5 restaurantes inolvidables en Ponce que debes visitar
# Restaurantes para celebrar en familia luego de la graduación
# 7 restaurantes frente al mar que debes probar durante Puerto Rico Restaurant Week
# Ocho clases que puedes tomar para salir de la rutina
# Lugares para tomar mojitos en las montañas de Puerto Rico
# Cocktail bars en San Juan que no te puedes perder
# 12 lugares para celebrar el Día de las Madres
# Ocho restaurantes que son hidden gems y no te debes perder
# Tu guía de heladerías locales para matar el antojo
# Restaurantes en Aibonito que no te puedes perder en tu próxima visita
# Siete restaurantes con comida hecha a la leña
# Ocho restaurantes en Caguas que debes visitar
# Restaurantes para comer seafood por Chef René Marichal
# Seis chocolaterías locales para endulzarte la vida
# 7 lugares de ramen que debes visitar
# Ocho lugares para hacer catering en Acción de Gracias
# Cuatro pastries únicos que tienes que probar
# Restaurantes para el wikén de Acción de Gracias
# Lugares de chinchorreo en el sur de Puerto Rico
# Ocho brunch spots en el oeste que tienes que visitar
# Seis lugares únicos en Aibonito para una visita inolvidable
# La ruta del lechón
# Lugares donde celebrar la víspera de año nuevo
# Siete paradas únicas en el Viejo San Juan
# 5 Experiencias cafetaleras en Puerto Rico
# Restaurantes de BBQ para saborear verano todo el año
# Ocho cosas que tienes que hacer si vives en Puerto Rico
# Siete restaurantes para disfrutar en familia
# Restaurantes abiertos los lunes en el área metro
# Restaurantes con vista al mar en San Juan
# Siete cenas de San Valentín en el área metro
# Siete restaurantes que abrirán este año y no te debes perder
# Ocho lugares únicos para sorprender a tu pareja
# Seis coffee spots que son hidden gems a través de la isla
# Restaurantes para transportarte a España en el área metro
# Los 7 restaurantes nuevos del Puerto Rico Restaurant Week
# 7 restaurantes fuera del área metro durante Puerto Rico Restaurant Week
# 7 pizzerías cerca de San Juan para los foodies más exigentes
# 6 spots con cervezas bien frías para ver el juego
# Restaurantes con <em>outdoor seating</em> en el área metropolitana
# 16 museos en Puerto Rico que tienes que visitar
# Restaurantes veganos que debes probar en Puerto Rico
# Restaurantes italianos auténticos en San Juan
# Date ideas únicos por menos de $50 para triunfar con tu pareja
# Ideas de citas únicas para impresionar a tu pareja
# Kioskos en Piñones para matar los munchies después de la playa
# Ocho barras con vista al mar para visitar en Puerto Rico
# 8 lugares con buenos especiales de almuerzo por $12 o menos
# Librerías locales con café para refugiarte durante los días lluviosos
# Restaurantes para saborear en Cabo Rojo en un día de playa
# Coffee shops para coffee lovers en San Juan
# Nueve panaderías artesanales alrededor de la isla para saciar tus antojos
# Restaurantes y coffee shops locales abiertos tras el paso de Fiona por la isla
# Brunch spots en el área metro para añadir a tu lista
# Lugares pet-friendly para llevar a tu mascota en Puerto Rico
# Rooftops que tienes que visitar en Puerto Rico
# Todo lo que puedes hacer en Caguas con solo $30
# 8 terrazas únicas donde puedes tomarte un buen café
# Nuevos restaurantes en la zona metro que hay que probar sí o sí en agosto
# Restaurant Spotlight: Ombra Italian Eatery
# Spots en el oeste para ver la puesta del sol
# Cafés cosechados en Puerto Rico que tienes que probar
# ¿Llueve? 10 actividades para aprovechar el fin de semana largo con lluvia
# Seis heladerías pet-friendly para sobrevivir el calor del verano en familia
# De roadtrip por Trujillo Alto en busca de historia, cultura y helados veganos
# Lugares en Puerto Rico para endulzarse con postres veganos
# Lugares para degustar cervezas artesanales en Puerto Rico
# Seis brunch spots en el Viejo San Juan para visitar este wikén
# Restaurantes para comer delicioso y <em>on a budget&nbsp;</em>
# Sushi spots en San Juan para transportar tu paladar a Asia
# Restaurantes con <em>waffles </em>únicos para probar&nbsp;
# 5 Restaurantes en el centro de Mayagüez que tienes que probar
# 5 actividades y jangueos sanos para días lluviosos en Puerto Rico
# Qué hacer y comer con $30 en la Calle Loíza
# Restaurantes románticos para tu date night en San Juan
# 7 barras para visitar después de un día largo de trabajo
# Tours agroturísticos divertidos para hacer en familia
#
#
# Cluster ---------------------------------------------------------------------------2
# 8 actividades para tu bucket list de vacaciones
# De Roadtrip por Aguadilla
# De road trip por Cabo Rojo
# Ocho actividades que debes hacer en Lajas
# Airbnbs en Puerto Rico que puedes alquilar para tus vacaciones
# Spots para hacer glamping en cinco pueblos de la isla
# Lugares que debes visitar en Utuado
# De road trip por las montañas de Cayey
# Experiencias únicas para hacer entre amistades
# Actividades para hacer al aire libre en Orocovis
# Boutique <em>hotels</em> para quedarte en Puerto Rico
# De road trip por la costa de Dorado
# Bed &amp; Breakfasts locales para recargar energía
# Trails en Puerto Rico para hacer mountain bike
# 7 haciendas para divertirse y salir de la rutina
# Restaurant Spotlight: Gylro
# Alquileres vacacionales con piscinas privadas en Puerto Rico
# Cosas que puedes hacer en tu visita a Jayuya
# Parques que puedes visitar para disfrutar con la familia
# 4 lugares donde vivir en la costa Oeste de Puerto Rico
# 6 lugares céntricos donde vivir en el área metro
# De road trip por la costa de Aguada
# Camping sites para una experiencia bajo las estrellas
# 6 playas para hacer snorkeling en Puerto Rico
# Restaurant Spotlight: Barullo Taberna Española
# Siete lugares para visitar en Salinas
# Peña Blanca: Combinación perfecta de ron, mar y tierra
# 5 cócteles con ron que debes probar y los platos para acompañarlos
# 2 cocteles con ron que debes probar luego de un día de playa en Culebra
# 5 playas escondidas para un fin de semana diferente
# De Roadtrip por Ponce, &#8220;La Perla del Sur&#8221;
# 11 actividades para hacer con tus niños este verano
# Nueve playas en Cabo Rojo para visitar este verano
# Rones y frituras: ¿Cuál escoger según tu ruta de chinchorreo?
# Siete lugares históricos para visitar en Puerto Rico
# 6 Airbnbs cerca de la playa para grupos pequeños o familias
# 6 Lugares para visitar en Yauco y disfrutar de las vacaciones
# Ocho actividades gratuitas para cerrar este verano como se debe
# 7 lugares que no debes perderte en Vega Baja
# Los mejores Airbnb&#8217;s en Puerto Rico por menos de $100 la noche
# 7 Airbnbs en el Viejo San Juan por menos de $150 la noche
# Join a Join y Airbnb&#8217;s con piscina disponibles este fin de semana largo
# Cinco spots únicos para paint and wine en el área metro
# 15 lugares que debes visitar en tus vacaciones de Semana Santa
# 7 cosas que puedes hacer en Cabo Rojo por $30
# 6 charcos y cascadas de fácil acceso para enfrentar la ola de calor
# Tu guía completa para visitar El Yunque
# Lugares para alquilar un catamarán en Puerto Rico
# Dónde quedarte si te das un trip a Cabo Rojo
# Venues únicos para alquilar en tu próxima actividad
# Cosas para hacer en 24 horas en el oeste
# Siete airbnbs para reconectar con la naturaleza
# Spots navideños para visitar en Puerto Rico
# Siete spots para correr patines si eres principiante
# Cinco chorreras naturales para zumbarte
# Seis plazas municipales que debes visitar en Puerto Rico
# Cinco excursiones únicas para hacer en grupo al aire libre
# Tu guía de cinco actividades para hacer en Las Marías
# Ocho treehouses para tus próximas vacaciones en Puerto Rico
#
#
# Cluster ---------------------------------------------------------------------------3
# Trap Kitty Festival: Young Miko convoca a sus gatitxs a un evento masivo en Mayagüez
# Distrito T-Mobile servirá como centro de acopio para brindar ayuda a los damnificados por el huracán Fiona
# Gobierno elimina de forma temporera el IVU en los alimentos preparados
# 4 maneras de ayudar a las comunidades de la zona oeste tras el paso del huracán Fiona
# Cancelación de eventos por el paso de la tormenta Fiona
# Volverán a elevar el globo de Jayuya
# 3 restaurantes que dan cátedra de recuperación tras Fiona
# ¿Hasta cuándo seguirá abierto Las Cascadas Water Park en Aguadilla?
# Jazz, laberintos embrujados y otras 8 actividades para este fin de semana en octubre
# Tu negocio podría recibir ayuda económica ante daños causados por el huracán Fiona
# ¡Día del Perro en Puerto Rico! Los 6 jangueos para celebrar con tu mascota
# Platea x Fine Wine Imports Cata Exclusiva
# ¿Qué es Platea?
# Spotlight: Mercado Agrícola Natural
# Un Verano Viewing Party: Lo que debes saber antes de llegar
# #PlateaPerks
# Restaurant Spotlight: Antillano
# Cierran fila para comprar taquillas para el concierto de Bad Bunny
# Estos son los precios de las taquillas para el concierto de Bad Bunny
# Eventos de navidad en Puerto Rico: 2021
# 5 tours de ron en la isla que no debes perderte
# 5 murales que debes visitar en Añasco
# Casa BACARDÍ Términos y Condiciones
# Terms of Use
# 7 marcas locales eco-amigables para todos los gustos
# Distrito T-Mobile celebrará su primer aniversario por todo lo alto y esto es lo que debes saber
# 9 eventos de Halloween que no te puedes perder esta semana

# %%
data = pd.read_csv('./data/text-similarity-documents.csv')
titles = [t for t in df['title']]

# %%
engines = [f"text-similarity-{e}-001" for e in ["ada", "babbage", "curie", "davinci"]]

for e in engines:
    current_embedding = pd.read_csv(f'./data/{e}.csv')
    print(e)
    plot_kmeans_elbow_chart(current_embedding, 10)
# Out:
# text-similarity-ada-001
# text-similarity-babbage-001
# text-similarity-curie-001
# text-similarity-davinci-001

# %%
for e in engines:
    current_embedding = pd.read_csv(f'./data/{e}.csv')
    print(e)
    plot_kmeans_elbow_chart(current_embedding, 10)

# %%
for e in engines:
    
    print(f'{e} starts ------------------------------------------------------------------------------------------------------------------------------------------')
    current_embedding = pd.read_csv(f'./data/{e}.csv')    
    ti = titles[0:len(current_embedding)]
    k_means_cluster_analysis(3, current_embedding.values, ti)
    print(f'{e} ends ------------------------------------------------------------------------------------------------------------------------------------------')
# Out:
# text-similarity-ada-001 starts ------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Clusters ---------------------------------------------------------------------------3
# 2    88
# 1    69
# 0    27
# Name: cluster, dtype: int64
#
#
# Cluster ---------------------------------------------------------------------------0
# 9 eventos de Halloween que no te puedes perder esta semana
# ¡Día del Perro en Puerto Rico! Los 6 jangueos para celebrar con tu mascota
# Distrito T-Mobile celebrará su primer aniversario por todo lo alto y esto es lo que debes saber
# Eventos de navidad en Puerto Rico: 2021
# Qué hacer y comer con $30 en la Calle Loíza
# Un Verano Viewing Party: Lo que debes saber antes de llegar
# Lugares donde celebrar la víspera de año nuevo
# Trap Kitty Festival: Young Miko convoca a sus gatitxs a un evento masivo en Mayagüez
# Cierran fila para comprar taquillas para el concierto de Bad Bunny
# Casa BACARDÍ Términos y Condiciones
# 5 actividades y jangueos sanos para días lluviosos en Puerto Rico
# Terms of Use
# Platea x Fine Wine Imports Cata Exclusiva
# #PlateaPerks
# 7 marcas locales eco-amigables para todos los gustos
# Estos son los precios de las taquillas para el concierto de Bad Bunny
# ¿Qué es Platea?
# 5 razones para visitar el Taste Food Fest en Plaza Las Américas
# Gobierno elimina de forma temporera el IVU en los alimentos preparados
# Distrito T-Mobile servirá como centro de acopio para brindar ayuda a los damnificados por el huracán Fiona
# 4 maneras de ayudar a las comunidades de la zona oeste tras el paso del huracán Fiona
# Cancelación de eventos por el paso de la tormenta Fiona
# Ocho clases que puedes tomar para salir de la rutina
# Volverán a elevar el globo de Jayuya
# Jazz, laberintos embrujados y otras 8 actividades para este fin de semana en octubre
# Tu negocio podría recibir ayuda económica ante daños causados por el huracán Fiona
# ¿Hasta cuándo seguirá abierto Las Cascadas Water Park en Aguadilla?
#
#
# Cluster ---------------------------------------------------------------------------1
# Alquileres vacacionales con piscinas privadas en Puerto Rico
# De Roadtrip por Ponce, &#8220;La Perla del Sur&#8221;
# 15 lugares que debes visitar en tus vacaciones de Semana Santa
# Cosas para hacer en 24 horas en el este
# Spots para hacer glamping en cinco pueblos de la isla
# Trails en Puerto Rico para hacer mountain bike
# Tu guía de cinco actividades para hacer en Las Marías
# Siete playas perfectas para escaparte y romper la rutina
# Seis lugares únicos en Aibonito para una visita inolvidable
# Actividades para divertirse en familia en Puerto Rico
# 12 lugares para celebrar el Día de las Madres
# Lugares que debes visitar en Utuado
# Cinco excursiones únicas para hacer en grupo al aire libre
# 7 cosas que puedes hacer en Cabo Rojo por $30
# Ocho treehouses para tus próximas vacaciones en Puerto Rico
# Dónde quedarte si te das un trip a Cabo Rojo
# Lugares para alquilar un catamarán en Puerto Rico
# Tu guía completa para visitar El Yunque
# Cosas para hacer en 24 horas en el oeste
# 6 playas para hacer snorkeling en Puerto Rico
# De Roadtrip por Aguadilla
# Venues únicos para alquilar en tu próxima actividad
# 7 haciendas para divertirse y salir de la rutina
# Ocho lugares para celebrar tu boda
# Ocho cosas que tienes que hacer si vives en Puerto Rico
# Cinco chorreras naturales para zumbarte
# 4 lugares donde vivir en la costa Oeste de Puerto Rico
# Tours agroturísticos divertidos para hacer en familia
# Spots navideños para visitar en Puerto Rico
# 6 lugares céntricos donde vivir en el área metro
# Siete lugares para visitar en Salinas
# 8 actividades para tu bucket list de vacaciones
# Actividades para hacer al aire libre en Orocovis
# Seis plazas municipales que debes visitar en Puerto Rico
# Siete spots para correr patines si eres principiante
# Siete airbnbs para reconectar con la naturaleza
# Experiencias únicas para hacer entre amistades
# 5 paradas que hacer en Isabela, Puerto Rico
# Ocho actividades que debes hacer en Lajas
# 7 Airbnbs en el Viejo San Juan por menos de $150 la noche
# 6 Airbnbs cerca de la playa para grupos pequeños o familias
# 6 Lugares para visitar en Yauco y disfrutar de las vacaciones
# ¿Llueve? 10 actividades para aprovechar el fin de semana largo con lluvia
# Cinco spots únicos para paint and wine en el área metro
# De road trip por la costa de Dorado
# Bucket list: 14 cosas para hacer este verano en Puerto Rico
# Bed &amp; Breakfasts locales para recargar energía
# Camping sites para una experiencia bajo las estrellas
# Ocho actividades gratuitas para cerrar este verano como se debe
# De road trip por la costa de Aguada
# 7 lugares que no debes perderte en Vega Baja
# Spots en el oeste para ver la puesta del sol
# Los mejores Airbnb&#8217;s en Puerto Rico por menos de $100 la noche
# Join a Join y Airbnb&#8217;s con piscina disponibles este fin de semana largo
# Rones y frituras: ¿Cuál escoger según tu ruta de chinchorreo?
# Siete lugares históricos para visitar en Puerto Rico
# 11 actividades para hacer con tus niños este verano
# 9 actividades para hacer en Guánica, el pueblo del eterno verano
# Boutique <em>hotels</em> para quedarte en Puerto Rico
# De road trip por Cabo Rojo
# 5 playas escondidas para un fin de semana diferente
# Nueve playas en Cabo Rojo para visitar este verano
# De road trip por las montañas de Cayey
# Parques que puedes visitar para disfrutar con la familia
# 16 museos en Puerto Rico que tienes que visitar
# Cosas que puedes hacer en tu visita a Jayuya
# 6 charcos y cascadas de fácil acceso para enfrentar la ola de calor
# Airbnbs en Puerto Rico que puedes alquilar para tus vacaciones
# 5 tours de ron en la isla que no debes perderte
#
#
# Cluster ---------------------------------------------------------------------------2
# La ruta del lechón
# Restaurantes para saborear en Cabo Rojo en un día de playa
# Lugares pet-friendly para llevar a tu mascota en Puerto Rico
# 7 lugares de ramen que debes visitar
# Ideas de citas únicas para impresionar a tu pareja
# Brunch spots en el área metro para añadir a tu lista
# Rooftops que tienes que visitar en Puerto Rico
# 5 Experiencias cafetaleras en Puerto Rico
# Restaurant Spotlight: Gylro
# Seis chocolaterías locales para endulzarte la vida
# Restaurantes italianos auténticos en San Juan
# Lugares en Puerto Rico para endulzarse con postres veganos
# Restaurantes para transportarte a España en el área metro
# Lugares para tomar mojitos en las montañas de Puerto Rico
# 5 restaurantes inolvidables en Ponce que debes visitar
# Restaurantes para comer delicioso y <em>on a budget&nbsp;</em>
# Lugares para degustar cervezas artesanales en Puerto Rico
# Cocktail bars en San Juan que no te puedes perder
# Restaurant Spotlight: Antillano
# 6 restaurantes con vista a las montañas
# Speakeasies que debes visitar en Puerto Rico
# Restaurantes para una experiencia farm-to-table
# Restaurantes de fine dining en Puerto Rico que debes probar
# Restaurantes para comer al aire libre
# Sushi spots en San Juan para transportar tu paladar a Asia
# Restaurant Spotlight: Ombra Italian Eatery
# Restaurantes con <em>outdoor seating</em> en el área metropolitana
# Restaurantes veganos que debes probar en Puerto Rico
# Restaurantes de BBQ para saborear verano todo el año
# Restaurantes con <em>waffles </em>únicos para probar&nbsp;
# Siete fincas locales que ofrecen servicio de delivery
# Siete restaurantes con comida hecha a la leña
# 7 restaurantes frente al mar que debes probar durante Puerto Rico Restaurant Week
# Los 7 restaurantes nuevos del Puerto Rico Restaurant Week
# Tu guía de heladerías locales para matar el antojo
# 7 restaurantes fuera del área metro durante Puerto Rico Restaurant Week
# 5 Restaurantes en el centro de Mayagüez que tienes que probar
# Seis heladerías pet-friendly para sobrevivir el calor del verano en familia
# 17 paradas obligatorias para hacer en Rincón, Puerto Rico
# Seis brunch spots en el Viejo San Juan para visitar este wikén
# 7 barras para visitar después de un día largo de trabajo
# Restaurantes románticos para tu date night en San Juan
# De roadtrip por Trujillo Alto en busca de historia, cultura y helados veganos
# Nuevos restaurantes en la zona metro que hay que probar sí o sí en agosto
# 7 pizzerías cerca de San Juan para los foodies más exigentes
# 6 spots con cervezas bien frías para ver el juego
# Date ideas únicos por menos de $50 para triunfar con tu pareja
# Kioskos en Piñones para matar los munchies después de la playa
# Ocho barras con vista al mar para visitar en Puerto Rico
# 8 lugares con buenos especiales de almuerzo por $12 o menos
# Librerías locales con café para refugiarte durante los días lluviosos
# Coffee shops para coffee lovers en San Juan
# Nueve panaderías artesanales alrededor de la isla para saciar tus antojos
# Restaurantes y coffee shops locales abiertos tras el paso de Fiona por la isla
# 3 restaurantes que dan cátedra de recuperación tras Fiona
# Todo lo que puedes hacer en Caguas con solo $30
# 8 terrazas únicas donde puedes tomarte un buen café
# Restaurantes para celebrar en familia luego de la graduación
# Restaurantes para comer seafood por Chef René Marichal
# Degustando Puerto Rico Restaurant Week (1-12 de junio de 2022)
# 2 cocteles con ron que debes probar luego de un día de playa en Culebra
# Cafés cosechados en Puerto Rico que tienes que probar
# Restaurantes en Aibonito que no te puedes perder en tu próxima visita
# Ocho restaurantes en Caguas que debes visitar
# Spotlight: Mercado Agrícola Natural
# Ocho lugares para hacer catering en Acción de Gracias
# Cuatro pastries únicos que tienes que probar
# Restaurantes para el wikén de Acción de Gracias
# Siete restaurantes en Isabela para comer en tu próxima visita
# Lugares de chinchorreo en el sur de Puerto Rico
# Ocho brunch spots en el oeste que tienes que visitar
# Seis coffee spots que son hidden gems a través de la isla
# Siete paradas únicas en el Viejo San Juan
# Siete restaurantes para disfrutar en familia
# Restaurantes abiertos los lunes en el área metro
# Restaurantes con vista al mar en San Juan
# Siete cenas de San Valentín en el área metro
# Siete restaurantes que abrirán este año y no te debes perder
# Ocho lugares únicos para sorprender a tu pareja
# Ocho restaurantes que son hidden gems y no te debes perder
# Seis restaurantes en Rincón que tienes que probar
# Seis espacios de co-working para mantenerte conectado si se va la luz
# Peña Blanca: Combinación perfecta de ron, mar y tierra
# Ruta por Lares: Qué hacer y dónde comer
# 5 cócteles con ron que debes probar y los platos para acompañarlos
# 5 spots para comer nachos fuera de este mundo
# 5 murales que debes visitar en Añasco
# Restaurant Spotlight: Barullo Taberna Española
#
#
# Cluster ---------------------------------------------------------------------------3
# text-similarity-ada-001 ends ------------------------------------------------------------------------------------------------------------------------------------------
# text-similarity-babbage-001 starts ------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Clusters ---------------------------------------------------------------------------3
# 0    92
# 2    66
# 1    26
# Name: cluster, dtype: int64
#
#
# Cluster ---------------------------------------------------------------------------0
# Siete fincas locales que ofrecen servicio de delivery
# Restaurantes en Aibonito que no te puedes perder en tu próxima visita
# Ocho restaurantes en Caguas que debes visitar
# Spotlight: Mercado Agrícola Natural
# Ocho lugares para hacer catering en Acción de Gracias
# Cuatro pastries únicos que tienes que probar
# Restaurantes para el wikén de Acción de Gracias
# Siete restaurantes en Isabela para comer en tu próxima visita
# Lugares de chinchorreo en el sur de Puerto Rico
# Ocho brunch spots en el oeste que tienes que visitar
# Seis coffee spots que son hidden gems a través de la isla
# Siete paradas únicas en el Viejo San Juan
# Siete restaurantes para disfrutar en familia
# Restaurantes abiertos los lunes en el área metro
# Restaurantes con vista al mar en San Juan
# Siete cenas de San Valentín en el área metro
# Siete restaurantes que abrirán este año y no te debes perder
# Ocho lugares únicos para sorprender a tu pareja
# Ocho restaurantes que son hidden gems y no te debes perder
# Seis restaurantes en Rincón que tienes que probar
# Seis espacios de co-working para mantenerte conectado si se va la luz
# Peña Blanca: Combinación perfecta de ron, mar y tierra
# 5 cócteles con ron que debes probar y los platos para acompañarlos
# 12 lugares para celebrar el Día de las Madres
# 5 spots para comer nachos fuera de este mundo
# 2 cocteles con ron que debes probar luego de un día de playa en Culebra
# 5 murales que debes visitar en Añasco
# Degustando Puerto Rico Restaurant Week (1-12 de junio de 2022)
# Cafés cosechados en Puerto Rico que tienes que probar
# Siete restaurantes con comida hecha a la leña
# Restaurantes para comer seafood por Chef René Marichal
# Seis chocolaterías locales para endulzarte la vida
# Rooftops que tienes que visitar en Puerto Rico
# Lugares pet-friendly para llevar a tu mascota en Puerto Rico
# Brunch spots en el área metro para añadir a tu lista
# Restaurantes para saborear en Cabo Rojo en un día de playa
# Restaurant Spotlight: Gylro
# Ideas de citas únicas para impresionar a tu pareja
# Restaurantes italianos auténticos en San Juan
# Restaurantes veganos que debes probar en Puerto Rico
# Restaurantes con <em>outdoor seating</em> en el área metropolitana
# Restaurant Spotlight: Ombra Italian Eatery
# Restaurantes con <em>waffles </em>únicos para probar&nbsp;
# Sushi spots en San Juan para transportar tu paladar a Asia
# Restaurant Spotlight: Antillano
# Restaurantes para celebrar en familia luego de la graduación
# Lugares para degustar cervezas artesanales en Puerto Rico
# Lugares en Puerto Rico para endulzarse con postres veganos
# Restaurantes para transportarte a España en el área metro
# Lugares para tomar mojitos en las montañas de Puerto Rico
# 5 restaurantes inolvidables en Ponce que debes visitar
# Cocktail bars en San Juan que no te puedes perder
# Speakeasies que debes visitar en Puerto Rico
# Restaurantes para una experiencia farm-to-table
# Restaurantes de fine dining en Puerto Rico que debes probar
# Restaurantes para comer al aire libre
# Restaurantes de BBQ para saborear verano todo el año
# 5 Experiencias cafetaleras en Puerto Rico
# La ruta del lechón
# 7 lugares de ramen que debes visitar
# Restaurantes para comer delicioso y <em>on a budget&nbsp;</em>
# 7 restaurantes frente al mar que debes probar durante Puerto Rico Restaurant Week
# Restaurant Spotlight: Barullo Taberna Española
# Cinco spots únicos para paint and wine en el área metro
# Seis brunch spots en el Viejo San Juan para visitar este wikén
# Seis heladerías pet-friendly para sobrevivir el calor del verano en familia
# Coffee shops para coffee lovers en San Juan
# 7 barras para visitar después de un día largo de trabajo
# Librerías locales con café para refugiarte durante los días lluviosos
# Nueve panaderías artesanales alrededor de la isla para saciar tus antojos
# 5 actividades y jangueos sanos para días lluviosos en Puerto Rico
# Restaurantes y coffee shops locales abiertos tras el paso de Fiona por la isla
# 8 lugares con buenos especiales de almuerzo por $12 o menos
# Rones y frituras: ¿Cuál escoger según tu ruta de chinchorreo?
# Ocho barras con vista al mar para visitar en Puerto Rico
# Restaurantes románticos para tu date night en San Juan
# 3 restaurantes que dan cátedra de recuperación tras Fiona
# De roadtrip por Trujillo Alto en busca de historia, cultura y helados veganos
# Kioskos en Piñones para matar los munchies después de la playa
# 17 paradas obligatorias para hacer en Rincón, Puerto Rico
# Nuevos restaurantes en la zona metro que hay que probar sí o sí en agosto
# Los 7 restaurantes nuevos del Puerto Rico Restaurant Week
# 8 terrazas únicas donde puedes tomarte un buen café
# Tu guía de heladerías locales para matar el antojo
# 5 tours de ron en la isla que no debes perderte
# 16 museos en Puerto Rico que tienes que visitar
# 7 restaurantes fuera del área metro durante Puerto Rico Restaurant Week
# Todo lo que puedes hacer en Caguas con solo $30
# 5 Restaurantes en el centro de Mayagüez que tienes que probar
# Date ideas únicos por menos de $50 para triunfar con tu pareja
# 6 spots con cervezas bien frías para ver el juego
# 7 pizzerías cerca de San Juan para los foodies más exigentes
#
#
# Cluster ---------------------------------------------------------------------------1
# ¿Qué es Platea?
# Un Verano Viewing Party: Lo que debes saber antes de llegar
# 5 razones para visitar el Taste Food Fest en Plaza Las Américas
# ¡Día del Perro en Puerto Rico! Los 6 jangueos para celebrar con tu mascota
# Trap Kitty Festival: Young Miko convoca a sus gatitxs a un evento masivo en Mayagüez
# ¿Hasta cuándo seguirá abierto Las Cascadas Water Park en Aguadilla?
# Cierran fila para comprar taquillas para el concierto de Bad Bunny
# Qué hacer y comer con $30 en la Calle Loíza
# Ocho clases que puedes tomar para salir de la rutina
# 9 eventos de Halloween que no te puedes perder esta semana
# 4 maneras de ayudar a las comunidades de la zona oeste tras el paso del huracán Fiona
# #PlateaPerks
# Jazz, laberintos embrujados y otras 8 actividades para este fin de semana en octubre
# Terms of Use
# Eventos de navidad en Puerto Rico: 2021
# Distrito T-Mobile servirá como centro de acopio para brindar ayuda a los damnificados por el huracán Fiona
# Casa BACARDÍ Términos y Condiciones
# Tu negocio podría recibir ayuda económica ante daños causados por el huracán Fiona
# Gobierno elimina de forma temporera el IVU en los alimentos preparados
# 7 marcas locales eco-amigables para todos los gustos
# Cancelación de eventos por el paso de la tormenta Fiona
# Volverán a elevar el globo de Jayuya
# Lugares donde celebrar la víspera de año nuevo
# Estos son los precios de las taquillas para el concierto de Bad Bunny
# Distrito T-Mobile celebrará su primer aniversario por todo lo alto y esto es lo que debes saber
# Platea x Fine Wine Imports Cata Exclusiva
#
#
# Cluster ---------------------------------------------------------------------------2
# 6 restaurantes con vista a las montañas
# Airbnbs en Puerto Rico que puedes alquilar para tus vacaciones
# Join a Join y Airbnb&#8217;s con piscina disponibles este fin de semana largo
# Cosas para hacer en 24 horas en el este
# Actividades para divertirse en familia en Puerto Rico
# De road trip por Cabo Rojo
# De road trip por las montañas de Cayey
# Cosas que puedes hacer en tu visita a Jayuya
# De road trip por la costa de Dorado
# Bed &amp; Breakfasts locales para recargar energía
# Trails en Puerto Rico para hacer mountain bike
# Parques que puedes visitar para disfrutar con la familia
# Lugares que debes visitar en Utuado
# De road trip por la costa de Aguada
# Tours agroturísticos divertidos para hacer en familia
# Experiencias únicas para hacer entre amistades
# Camping sites para una experiencia bajo las estrellas
# Boutique <em>hotels</em> para quedarte en Puerto Rico
# Alquileres vacacionales con piscinas privadas en Puerto Rico
# Actividades para hacer al aire libre en Orocovis
# 9 actividades para hacer en Guánica, el pueblo del eterno verano
# 4 lugares donde vivir en la costa Oeste de Puerto Rico
# Siete spots para correr patines si eres principiante
# Cinco chorreras naturales para zumbarte
# ¿Llueve? 10 actividades para aprovechar el fin de semana largo con lluvia
# 6 Lugares para visitar en Yauco y disfrutar de las vacaciones
# 6 Airbnbs cerca de la playa para grupos pequeños o familias
# Siete lugares históricos para visitar en Puerto Rico
# Bucket list: 14 cosas para hacer este verano en Puerto Rico
# Cinco excursiones únicas para hacer en grupo al aire libre
# Seis lugares únicos en Aibonito para una visita inolvidable
# Siete playas perfectas para escaparte y romper la rutina
# Tu guía de cinco actividades para hacer en Las Marías
# Ocho treehouses para tus próximas vacaciones en Puerto Rico
# Nueve playas en Cabo Rojo para visitar este verano
# 11 actividades para hacer con tus niños este verano
# 7 cosas que puedes hacer en Cabo Rojo por $30
# 15 lugares que debes visitar en tus vacaciones de Semana Santa
# Ruta por Lares: Qué hacer y dónde comer
# 6 charcos y cascadas de fácil acceso para enfrentar la ola de calor
# 5 playas escondidas para un fin de semana diferente
# Seis plazas municipales que debes visitar en Puerto Rico
# 6 lugares céntricos donde vivir en el área metro
# Spots navideños para visitar en Puerto Rico
# Ocho lugares para celebrar tu boda
# Ocho cosas que tienes que hacer si vives en Puerto Rico
# Spots en el oeste para ver la puesta del sol
# 7 Airbnbs en el Viejo San Juan por menos de $150 la noche
# 7 haciendas para divertirse y salir de la rutina
# 6 playas para hacer snorkeling en Puerto Rico
# De Roadtrip por Aguadilla
# 8 actividades para tu bucket list de vacaciones
# Ocho actividades que debes hacer en Lajas
# Los mejores Airbnb&#8217;s en Puerto Rico por menos de $100 la noche
# 5 paradas que hacer en Isabela, Puerto Rico
# De Roadtrip por Ponce, &#8220;La Perla del Sur&#8221;
# Siete lugares para visitar en Salinas
# Venues únicos para alquilar en tu próxima actividad
# Lugares para alquilar un catamarán en Puerto Rico
# Dónde quedarte si te das un trip a Cabo Rojo
# Tu guía completa para visitar El Yunque
# Cosas para hacer en 24 horas en el oeste
# 7 lugares que no debes perderte en Vega Baja
# Ocho actividades gratuitas para cerrar este verano como se debe
# Siete airbnbs para reconectar con la naturaleza
# Spots para hacer glamping en cinco pueblos de la isla
#
#
# Cluster ---------------------------------------------------------------------------3
# text-similarity-babbage-001 ends ------------------------------------------------------------------------------------------------------------------------------------------
# text-similarity-curie-001 starts ------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Clusters ---------------------------------------------------------------------------3
# 0    87
# 1    71
# 2    26
# Name: cluster, dtype: int64
#
#
# Cluster ---------------------------------------------------------------------------0
# Siete fincas locales que ofrecen servicio de delivery
# Cafés cosechados en Puerto Rico que tienes que probar
# Restaurantes en Aibonito que no te puedes perder en tu próxima visita
# Venues únicos para alquilar en tu próxima actividad
# Ocho restaurantes en Caguas que debes visitar
# Spotlight: Mercado Agrícola Natural
# Ocho lugares para hacer catering en Acción de Gracias
# Cuatro pastries únicos que tienes que probar
# Restaurantes para el wikén de Acción de Gracias
# Siete restaurantes en Isabela para comer en tu próxima visita
# Lugares de chinchorreo en el sur de Puerto Rico
# Ocho brunch spots en el oeste que tienes que visitar
# Seis coffee spots que son hidden gems a través de la isla
# Siete paradas únicas en el Viejo San Juan
# Siete restaurantes para disfrutar en familia
# Restaurantes abiertos los lunes en el área metro
# Restaurantes con vista al mar en San Juan
# Siete cenas de San Valentín en el área metro
# Siete restaurantes que abrirán este año y no te debes perder
# Ocho lugares únicos para sorprender a tu pareja
# Ocho restaurantes que son hidden gems y no te debes perder
# Seis restaurantes en Rincón que tienes que probar
# Seis espacios de co-working para mantenerte conectado si se va la luz
# Peña Blanca: Combinación perfecta de ron, mar y tierra
# 5 cócteles con ron que debes probar y los platos para acompañarlos
# 5 spots para comer nachos fuera de este mundo
# 2 cocteles con ron que debes probar luego de un día de playa en Culebra
# 5 murales que debes visitar en Añasco
# Siete restaurantes con comida hecha a la leña
# Restaurantes para celebrar en familia luego de la graduación
# Restaurantes para comer seafood por Chef René Marichal
# 7 lugares de ramen que debes visitar
# Rooftops que tienes que visitar en Puerto Rico
# Lugares pet-friendly para llevar a tu mascota en Puerto Rico
# Brunch spots en el área metro para añadir a tu lista
# Restaurantes para saborear en Cabo Rojo en un día de playa
# Restaurant Spotlight: Gylro
# Ideas de citas únicas para impresionar a tu pareja
# Restaurantes italianos auténticos en San Juan
# Restaurantes veganos que debes probar en Puerto Rico
# Restaurantes con <em>outdoor seating</em> en el área metropolitana
# Restaurant Spotlight: Ombra Italian Eatery
# Restaurantes con <em>waffles </em>únicos para probar&nbsp;
# Sushi spots en San Juan para transportar tu paladar a Asia
# Restaurant Spotlight: Antillano
# Lugares para degustar cervezas artesanales en Puerto Rico
# Restaurantes para comer delicioso y <em>on a budget&nbsp;</em>
# Lugares en Puerto Rico para endulzarse con postres veganos
# Restaurantes para transportarte a España en el área metro
# Lugares para tomar mojitos en las montañas de Puerto Rico
# 5 restaurantes inolvidables en Ponce que debes visitar
# Cocktail bars en San Juan que no te puedes perder
# 6 restaurantes con vista a las montañas
# Speakeasies que debes visitar en Puerto Rico
# Restaurantes para una experiencia farm-to-table
# Restaurantes de fine dining en Puerto Rico que debes probar
# Restaurantes para comer al aire libre
# Restaurantes de BBQ para saborear verano todo el año
# La ruta del lechón
# Seis chocolaterías locales para endulzarte la vida
# 7 restaurantes frente al mar que debes probar durante Puerto Rico Restaurant Week
# Restaurant Spotlight: Barullo Taberna Española
# De roadtrip por Trujillo Alto en busca de historia, cultura y helados veganos
# Date ideas únicos por menos de $50 para triunfar con tu pareja
# Kioskos en Piñones para matar los munchies después de la playa
# Restaurantes románticos para tu date night en San Juan
# Ocho barras con vista al mar para visitar en Puerto Rico
# 8 lugares con buenos especiales de almuerzo por $12 o menos
# Rones y frituras: ¿Cuál escoger según tu ruta de chinchorreo?
# Librerías locales con café para refugiarte durante los días lluviosos
# Seis brunch spots en el Viejo San Juan para visitar este wikén
# 7 barras para visitar después de un día largo de trabajo
# 6 spots con cervezas bien frías para ver el juego
# Coffee shops para coffee lovers en San Juan
# Nueve panaderías artesanales alrededor de la isla para saciar tus antojos
# 5 Restaurantes en el centro de Mayagüez que tienes que probar
# Cinco spots únicos para paint and wine en el área metro
# Seis heladerías pet-friendly para sobrevivir el calor del verano en familia
# Los 7 restaurantes nuevos del Puerto Rico Restaurant Week
# 3 restaurantes que dan cátedra de recuperación tras Fiona
# 7 pizzerías cerca de San Juan para los foodies más exigentes
# Nuevos restaurantes en la zona metro que hay que probar sí o sí en agosto
# 7 restaurantes fuera del área metro durante Puerto Rico Restaurant Week
# 8 terrazas únicas donde puedes tomarte un buen café
# Restaurantes y coffee shops locales abiertos tras el paso de Fiona por la isla
# Qué hacer y comer con $30 en la Calle Loíza
# Tu guía de heladerías locales para matar el antojo
#
#
# Cluster ---------------------------------------------------------------------------1
# 6 lugares céntricos donde vivir en el área metro
# 4 lugares donde vivir en la costa Oeste de Puerto Rico
# Ocho cosas que tienes que hacer si vives en Puerto Rico
# 7 Airbnbs en el Viejo San Juan por menos de $150 la noche
# 8 actividades para tu bucket list de vacaciones
# 5 Experiencias cafetaleras en Puerto Rico
# Ocho actividades que debes hacer en Lajas
# 7 haciendas para divertirse y salir de la rutina
# 6 playas para hacer snorkeling en Puerto Rico
# Actividades para hacer al aire libre en Orocovis
# De Roadtrip por Aguadilla
# Spots para hacer glamping en cinco pueblos de la isla
# Los mejores Airbnb&#8217;s en Puerto Rico por menos de $100 la noche
# Trails en Puerto Rico para hacer mountain bike
# Cosas para hacer en 24 horas en el este
# De road trip por Cabo Rojo
# Todo lo que puedes hacer en Caguas con solo $30
# De road trip por las montañas de Cayey
# Airbnbs en Puerto Rico que puedes alquilar para tus vacaciones
# De road trip por la costa de Dorado
# Bed &amp; Breakfasts locales para recargar energía
# Parques que puedes visitar para disfrutar con la familia
# De road trip por la costa de Aguada
# Cosas que puedes hacer en tu visita a Jayuya
# Boutique <em>hotels</em> para quedarte en Puerto Rico
# Camping sites para una experiencia bajo las estrellas
# Experiencias únicas para hacer entre amistades
# Tours agroturísticos divertidos para hacer en familia
# Lugares que debes visitar en Utuado
# Alquileres vacacionales con piscinas privadas en Puerto Rico
# Join a Join y Airbnb&#8217;s con piscina disponibles este fin de semana largo
# Actividades para divertirse en familia en Puerto Rico
# Spots en el oeste para ver la puesta del sol
# 9 actividades para hacer en Guánica, el pueblo del eterno verano
# 5 paradas que hacer en Isabela, Puerto Rico
# Ocho clases que puedes tomar para salir de la rutina
# Cinco chorreras naturales para zumbarte
# 6 Lugares para visitar en Yauco y disfrutar de las vacaciones
# 5 actividades y jangueos sanos para días lluviosos en Puerto Rico
# 6 Airbnbs cerca de la playa para grupos pequeños o familias
# Siete lugares históricos para visitar en Puerto Rico
# De Roadtrip por Ponce, &#8220;La Perla del Sur&#8221;
# Cinco excursiones únicas para hacer en grupo al aire libre
# Nueve playas en Cabo Rojo para visitar este verano
# Seis lugares únicos en Aibonito para una visita inolvidable
# Siete spots para correr patines si eres principiante
# Siete playas perfectas para escaparte y romper la rutina
# Ocho treehouses para tus próximas vacaciones en Puerto Rico
# 11 actividades para hacer con tus niños este verano
# 7 cosas que puedes hacer en Cabo Rojo por $30
# 15 lugares que debes visitar en tus vacaciones de Semana Santa
# 6 charcos y cascadas de fácil acceso para enfrentar la ola de calor
# Ruta por Lares: Qué hacer y dónde comer
# 16 museos en Puerto Rico que tienes que visitar
# 5 tours de ron en la isla que no debes perderte
# 5 playas escondidas para un fin de semana diferente
# Tu guía de cinco actividades para hacer en Las Marías
# Seis plazas municipales que debes visitar en Puerto Rico
# Bucket list: 14 cosas para hacer este verano en Puerto Rico
# ¿Llueve? 10 actividades para aprovechar el fin de semana largo con lluvia
# 7 lugares que no debes perderte en Vega Baja
# Tu guía completa para visitar El Yunque
# Cosas para hacer en 24 horas en el oeste
# Ocho actividades gratuitas para cerrar este verano como se debe
# Ocho lugares para celebrar tu boda
# 17 paradas obligatorias para hacer en Rincón, Puerto Rico
# Lugares para alquilar un catamarán en Puerto Rico
# Siete airbnbs para reconectar con la naturaleza
# Spots navideños para visitar en Puerto Rico
# Siete lugares para visitar en Salinas
# Dónde quedarte si te das un trip a Cabo Rojo
#
#
# Cluster ---------------------------------------------------------------------------2
# Jazz, laberintos embrujados y otras 8 actividades para este fin de semana en octubre
# Tu negocio podría recibir ayuda económica ante daños causados por el huracán Fiona
# Un Verano Viewing Party: Lo que debes saber antes de llegar
# ¿Qué es Platea?
# 7 marcas locales eco-amigables para todos los gustos
# 5 razones para visitar el Taste Food Fest en Plaza Las Américas
# Degustando Puerto Rico Restaurant Week (1-12 de junio de 2022)
# 4 maneras de ayudar a las comunidades de la zona oeste tras el paso del huracán Fiona
# Distrito T-Mobile servirá como centro de acopio para brindar ayuda a los damnificados por el huracán Fiona
# 12 lugares para celebrar el Día de las Madres
# Cancelación de eventos por el paso de la tormenta Fiona
# #PlateaPerks
# Platea x Fine Wine Imports Cata Exclusiva
# Trap Kitty Festival: Young Miko convoca a sus gatitxs a un evento masivo en Mayagüez
# Volverán a elevar el globo de Jayuya
# Terms of Use
# ¿Hasta cuándo seguirá abierto Las Cascadas Water Park en Aguadilla?
# Cierran fila para comprar taquillas para el concierto de Bad Bunny
# Casa BACARDÍ Términos y Condiciones
# Estos son los precios de las taquillas para el concierto de Bad Bunny
# Eventos de navidad en Puerto Rico: 2021
# Lugares donde celebrar la víspera de año nuevo
# Distrito T-Mobile celebrará su primer aniversario por todo lo alto y esto es lo que debes saber
# ¡Día del Perro en Puerto Rico! Los 6 jangueos para celebrar con tu mascota
# Gobierno elimina de forma temporera el IVU en los alimentos preparados
# 9 eventos de Halloween que no te puedes perder esta semana
#
#
# Cluster ---------------------------------------------------------------------------3
# text-similarity-curie-001 ends ------------------------------------------------------------------------------------------------------------------------------------------
# text-similarity-davinci-001 starts ------------------------------------------------------------------------------------------------------------------------------------------
#
#
# Clusters ---------------------------------------------------------------------------3
# 2    57
# 1    31
# 0    18
# Name: cluster, dtype: int64
#
#
# Cluster ---------------------------------------------------------------------------0
# 11 actividades para hacer con tus niños este verano
# 7 pizzerías cerca de San Juan para los foodies más exigentes
# Ocho restaurantes que son hidden gems y no te debes perder
# Ocho actividades gratuitas para cerrar este verano como se debe
# 17 paradas obligatorias para hacer en Rincón, Puerto Rico
# Siete lugares históricos para visitar en Puerto Rico
# Ocho barras con vista al mar para visitar en Puerto Rico
# Bucket list: 14 cosas para hacer este verano en Puerto Rico
# Siete cenas de San Valentín en el área metro
# 16 museos en Puerto Rico que tienes que visitar
# Nueve playas en Cabo Rojo para visitar este verano
# Ocho lugares únicos para sorprender a tu pareja
# Tu guía de heladerías locales para matar el antojo
# 5 playas escondidas para un fin de semana diferente
# 9 actividades para hacer en Guánica, el pueblo del eterno verano
# 15 lugares que debes visitar en tus vacaciones de Semana Santa
# Nueve panaderías artesanales alrededor de la isla para saciar tus antojos
# Restaurantes para celebrar en familia luego de la graduación
#
#
# Cluster ---------------------------------------------------------------------------1
# 2 cocteles con ron que debes probar luego de un día de playa en Culebra
# Un Verano Viewing Party: Lo que debes saber antes de llegar
# Casa BACARDÍ Términos y Condiciones
# Peña Blanca: Combinación perfecta de ron, mar y tierra
# Degustando Puerto Rico Restaurant Week (1-12 de junio de 2022)
# 5 tours de ron en la isla que no debes perderte
# Estos son los precios de las taquillas para el concierto de Bad Bunny
# Los 7 restaurantes nuevos del Puerto Rico Restaurant Week
# Rones y frituras: ¿Cuál escoger según tu ruta de chinchorreo?
# Platea x Fine Wine Imports Cata Exclusiva
# #PlateaPerks
# Cierran fila para comprar taquillas para el concierto de Bad Bunny
# Terms of Use
# 5 cócteles con ron que debes probar y los platos para acompañarlos
# Trap Kitty Festival: Young Miko convoca a sus gatitxs a un evento masivo en Mayagüez
# Gobierno elimina de forma temporera el IVU en los alimentos preparados
# Join a Join y Airbnb&#8217;s con piscina disponibles este fin de semana largo
# Tu negocio podría recibir ayuda económica ante daños causados por el huracán Fiona
# Distrito T-Mobile servirá como centro de acopio para brindar ayuda a los damnificados por el huracán Fiona
# Lugares donde celebrar la víspera de año nuevo
# 4 maneras de ayudar a las comunidades de la zona oeste tras el paso del huracán Fiona
# Spots navideños para visitar en Puerto Rico
# Volverán a elevar el globo de Jayuya
# Distrito T-Mobile celebrará su primer aniversario por todo lo alto y esto es lo que debes saber
# Jazz, laberintos embrujados y otras 8 actividades para este fin de semana en octubre
# 7 Airbnbs en el Viejo San Juan por menos de $150 la noche
# 5 razones para visitar el Taste Food Fest en Plaza Las Américas
# ¿Hasta cuándo seguirá abierto Las Cascadas Water Park en Aguadilla?
# Los mejores Airbnb&#8217;s en Puerto Rico por menos de $100 la noche
# Eventos de navidad en Puerto Rico: 2021
# Cancelación de eventos por el paso de la tormenta Fiona
#
#
# Cluster ---------------------------------------------------------------------------2
# Siete restaurantes que abrirán este año y no te debes perder
# Siete airbnbs para reconectar con la naturaleza
# Ocho brunch spots en el oeste que tienes que visitar
# 7 marcas locales eco-amigables para todos los gustos
# 7 cosas que puedes hacer en Cabo Rojo por $30
# Siete paradas únicas en el Viejo San Juan
# Seis coffee spots que son hidden gems a través de la isla
# Seis plazas municipales que debes visitar en Puerto Rico
# Siete spots para correr patines si eres principiante
# Seis restaurantes en Rincón que tienes que probar
# Ocho treehouses para tus próximas vacaciones en Puerto Rico
# Tu guía de cinco actividades para hacer en Las Marías
# Siete playas perfectas para escaparte y romper la rutina
# Cinco chorreras naturales para zumbarte
# Siete restaurantes para disfrutar en familia
# Seis lugares únicos en Aibonito para una visita inolvidable
# Restaurantes abiertos los lunes en el área metro
# Siete fincas locales que ofrecen servicio de delivery
# Ruta por Lares: Qué hacer y dónde comer
# Seis espacios de co-working para mantenerte conectado si se va la luz
# Cinco excursiones únicas para hacer en grupo al aire libre
# 9 eventos de Halloween que no te puedes perder esta semana
# 5 spots para comer nachos fuera de este mundo
# Nuevos restaurantes en la zona metro que hay que probar sí o sí en agosto
# 6 spots con cervezas bien frías para ver el juego
# Spots en el oeste para ver la puesta del sol
# ¡Día del Perro en Puerto Rico! Los 6 jangueos para celebrar con tu mascota
# Date ideas únicos por menos de $50 para triunfar con tu pareja
# Kioskos en Piñones para matar los munchies después de la playa
# De roadtrip por Trujillo Alto en busca de historia, cultura y helados veganos
# 8 lugares con buenos especiales de almuerzo por $12 o menos
# Cinco spots únicos para paint and wine en el área metro
# Coffee shops para coffee lovers en San Juan
# Restaurantes y coffee shops locales abiertos tras el paso de Fiona por la isla
# 3 restaurantes que dan cátedra de recuperación tras Fiona
# Todo lo que puedes hacer en Caguas con solo $30
# 8 terrazas únicas donde puedes tomarte un buen café
# Librerías locales con café para refugiarte durante los días lluviosos
# 12 lugares para celebrar el Día de las Madres
# Restaurantes románticos para tu date night en San Juan
# 7 lugares que no debes perderte en Vega Baja
# 5 murales que debes visitar en Añasco
# 7 restaurantes frente al mar que debes probar durante Puerto Rico Restaurant Week
# 5 paradas que hacer en Isabela, Puerto Rico
# 7 restaurantes fuera del área metro durante Puerto Rico Restaurant Week
# 6 charcos y cascadas de fácil acceso para enfrentar la ola de calor
# 5 Restaurantes en el centro de Mayagüez que tienes que probar
# Qué hacer y comer con $30 en la Calle Loíza
# Lugares de chinchorreo en el sur de Puerto Rico
# 5 actividades y jangueos sanos para días lluviosos en Puerto Rico
# 6 Lugares para visitar en Yauco y disfrutar de las vacaciones
# ¿Llueve? 10 actividades para aprovechar el fin de semana largo con lluvia
# Seis heladerías pet-friendly para sobrevivir el calor del verano en familia
# Seis brunch spots en el Viejo San Juan para visitar este wikén
# 7 barras para visitar después de un día largo de trabajo
# 6 Airbnbs cerca de la playa para grupos pequeños o familias
# Siete restaurantes en Isabela para comer en tu próxima visita
#
#
# Cluster ---------------------------------------------------------------------------3
# text-similarity-davinci-001 ends ------------------------------------------------------------------------------------------------------------------------------------------

# %%
# Out:
# 1024
