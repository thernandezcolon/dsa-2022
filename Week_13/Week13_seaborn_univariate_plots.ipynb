# %% [markdown]
# ## Week13 Advanced Visualizations with Seaborn, Part I
#
# [Seaborn is a visualization package](https://seaborn.pydata.org/) that leverages Matplotlib on the backend, but with a more elegant interface, and more aesthetically pleasing visuals. Seaborn is probably the most popular python plotting package for data scientists, much like ggplot2 is when working in R, and the two packages offer some similarities in their approach to plotting.
#
# This week will be a quick warmup to Seaborn, with plotting primarily in one variable. Next week we will tackle multivariate plots.

# %%
# If you have not already, install the pydataset package. 
# This package gives us data sets to work with very easily.
# You will also need the seaborn package.

! pip3 install pydataset
! pip3 install seaborn
# Out:
# Requirement already satisfied: pydataset in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (0.2.0)
# Requirement already satisfied: pandas in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from pydataset) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from pandas->pydataset) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from pandas->pydataset) (1.22.4)
# Requirement already satisfied: six>=1.5 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the '/Users/thernandezcolon/.pyenv/versions/3.9.10/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: seaborn in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (0.12.0)
# Requirement already satisfied: matplotlib>=3.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.25 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.17 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from seaborn) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: cycler>=0.10 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (4.37.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from matplotlib>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/thernandezcolon/.pyenv/versions/3.9.10/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 22.3 is available.
# You should consider upgrading via the '/Users/thernandezcolon/.pyenv/versions/3.9.10/bin/python3.9 -m pip install --upgrade pip' command.

# %%
# The convention for importing Seaborn is "sns". 

import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
from pydataset import data

# %% [markdown]
# ### About the Iris Data
#
# > "The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper The use of multiple measurements in taxonomic problems as an example of linear discriminant analysis. It is sometimes called Anderson's Iris data set because Edgar Anderson collected the data to quantify the morphologic variation of Iris flowers of three related species. Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".
#
# > The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters. Based on the combination of these four features, Fisher developed a linear discriminant model to distinguish the species from each other."
#
# *Source: [Wikipedia](https://en.wikipedia.org/wiki/Iris_flower_data_set)*

# %%
# The iris data set 
df = data("iris")

df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Question 1
#
# The description above claims that each species of iris has the same number of observations. Build a barplot of the counts of each observation to verify this fact.
#
# *HINT: Look at the documentation for Seaborn's countplot.*

# %%
# TODO
sns.countplot(x=df["Species"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# ## Question 2
#
# Do another barplot of the count of observations of species, but this time, only include observations with a petal length of at least 4 cm.

# %%
# TODO

filteted = df[df["Petal.Length"]>=4]

sns.countplot(x=filteted["Species"])
# Out:
# <AxesSubplot:xlabel='Species', ylabel='count'>

# %% [markdown]
# ## Question 3
#
# Seeing this plot, which species seems to have the longest petals of the three?
#
# virginica

# %% [markdown]
# ## Univariate Distributions
#
# Next up, lets take a look at various methods for plotting univariate distributions in Seaborn. Try these three methods of plotting the distribution of the Iris petal lengths with Seaborn:
#
# * Boxplot
# * Histogram
# * [Kernel density estimate](https://en.wikipedia.org/wiki/Kernel_density_estimation) plot

# %% [markdown]
# ## Question 4
#
# Plot the distribution of Iris petal lengths with a boxplot

# %%
# TODO
sns.boxplot( y=df["Petal.Length"], x=df["Species"] );

# %% [markdown]
# ## Question 5
#
# Plot the distribution of Iris petal lengths with a histogram

# %%
# TODO
sns.histplot(df["Petal.Length"])
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Count'>

# %% [markdown]
# ## Question 6
#
# Plot the distribution of Iris petal lengths with a kernel density estimate

# %%
# TODO
sns.displot(data=df, x='Petal.Length',kind='kde')

# %% [markdown]
# ## But What About Time Series?
#
# One of the goals this week was also to get you introduced to time series data, but the Iris data set doesn't have a time component to it. So for one final plot, let us examine the Lynx data set.

# %% [markdown]
# ### About the Lynx Data
#
# > "The Canadian lynx data set used in time series modelling is the annual record of the number of the Canadian lynx "trapped" in the Mackenzie River district of the North-West Canada for the period 1821–1934. These data are actually the total fur returns, or total sales, from the London archives of the Hudson's Bay Company in the years of 1821–1891 and 1887–1913; and those for 1915 to 1934 are from detailed statements supplied by the Company's Fur Trade Department in Winnipeg; those for 1892–1896 and 1914 are from a series of returns for the MacKenzie River District; those for the years 1863–1927 were supplied by Ch. French, then Fur Trade Commissioner of the Company in Canada. By considering the time lag between the year in which a lynx was trapped and the year in which its fur was sold at auction in London, these data were converted in into the number that were presumably caught in a given year for the years 1821–1934."
#
# *Source: [Encyclopedia of Mathematics](https://www.encyclopediaofmath.org/index.php/Canadian_lynx_data)*

# %%
lynx = data('lynx')

lynx.head()
# Out:
#    time  lynx
# 1  1821   269
# 2  1822   321
# 3  1823   585
# 4  1824   871
# 5  1825  1475

# %% [markdown]
# ## Question 7
#
# Generate the plot that follows. Pay attention the following characteristics:
# * The title
# * The xlabel has been removed
# * A custom set of xticks has been added, 10 years apart
# * The xticks have been rotated 45 degrees

# %% [markdown]
# <img src = "images/lynx_timeplot.png" style="width:420px">

# %%
# TODO

ticks = [v for v in range(1820, max(lynx['time']), 10)]
g = sns.lineplot(lynx, x="time", y="lynx")
g.set(title="Canadian Lynx Furs By Year, 1821-1934")
g.set(xlabel=None)
g.set_xticks(ticks)
plt.xticks(rotation=45)
# Out:
# (array([1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900, 1910, 1920,
#         1930]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
